# %%
# !pip install --upgrade numpy==1.17.2
# Out:
# Collecting numpy==1.17.2
#   Downloading numpy-1.17.2.zip (6.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.5/6.5 MB 48.4 MB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: numpy
#   Building wheel for numpy (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [2902 lines of output]
#       Running from numpy source directory.
#       blas_opt_info:
#       blas_mkl_info:
#       customize UnixCCompiler
#         FOUND:
#           libraries = ['mkl_rt', 'pthread']
#           library_dirs = ['/opt/conda/lib']
#           define_macros = [('SCIPY_MKL_H', None), ('HAVE_CBLAS', None)]
#           include_dirs = ['/usr/local/include', '/usr/include', '/opt/conda/include']
#
#         FOUND:
#           libraries = ['mkl_rt', 'pthread']
#           library_dirs = ['/opt/conda/lib']
#           define_macros = [('SCIPY_MKL_H', None), ('HAVE_CBLAS', None)]
#           include_dirs = ['/usr/local/include', '/usr/include', '/opt/conda/include']
#
#       /bin/sh: 1: svnversion: not found
#       non-existing path in 'numpy/distutils': 'site.cfg'
#       lapack_opt_info:
#       lapack_mkl_info:
#       customize UnixCCompiler
#         FOUND:
#           libraries = ['mkl_rt', 'pthread']
#           library_dirs = ['/opt/conda/lib']
#           define_macros = [('SCIPY_MKL_H', None), ('HAVE_CBLAS', None)]
#           include_dirs = ['/usr/local/include', '/usr/include', '/opt/conda/include']
#
#         FOUND:
#           libraries = ['mkl_rt', 'pthread']
#           library_dirs = ['/opt/conda/lib']
#           define_macros = [('SCIPY_MKL_H', None), ('HAVE_CBLAS', None)]
#           include_dirs = ['/usr/local/include', '/usr/include', '/opt/conda/include']
#
#       non-existing path in 'numpy/random': 'src/splitmix64/splitmix.h'
#       /opt/conda/lib/python3.10/distutils/dist.py:274: UserWarning: Unknown distribution option: 'define_macros'
#         warnings.warn(msg)
#       running bdist_wheel
#       running build
#       running config_cc
#       unifing config_cc, config, build_clib, build_ext, build commands --compiler options
#       running config_fc
#       unifing config_fc, config, build_clib, build_ext, build commands --fcompiler options
#       running build_src
#       build_src
#       building py_modules sources
#       creating build
#       creating build/src.linux-x86_64-3.1
#       creating build/src.linux-x86_64-3.1/numpy
#       creating build/src.linux-x86_64-3.1/numpy/distutils
#       building library "npymath" sources
#       get_default_fcompiler: matching types: '['gnu95', 'intel', 'lahey', 'pg', 'absoft', 'nag', 'vast', 'compaq', 'intele', 'intelem', 'gnu', 'g95', 'pathf95', 'nagfor']'
#       customize Gnu95FCompiler
#       Could not locate executable gfortran
#       Could not locate executable f95
#       customize IntelFCompiler
#       Could not locate executable ifort
#       Could not locate executable ifc
#       customize LaheyFCompiler
#       Could not locate executable lf95
#       customize PGroupFCompiler
#       Could not locate executable pgfortran
#       customize AbsoftFCompiler
#       Could not locate executable f90
#       Could not locate executable f77
#       customize NAGFCompiler
#       customize VastFCompiler
#       customize CompaqFCompiler
#       Could not locate executable fort
#       customize IntelItaniumFCompiler
#       Could not locate executable efort
#       Could not locate executable efc
#       customize IntelEM64TFCompiler
#       customize GnuFCompiler
#       Could not locate executable g77
#       customize G95FCompiler
#       Could not locate executable g95
#       customize PathScaleFCompiler
#       Could not locate executable pathf95
#       customize NAGFORCompiler
#       Could not locate executable nagfor
#       don't know how to compile Fortran code on platform 'posix'
#       C compiler: gcc -pthread -B /opt/conda/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/conda/include -fPIC -O2 -isystem /opt/conda/include -fPIC
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/opt/conda/include/python3.10 -c'
#       gcc: _configtest.c
#       gcc -pthread -B /opt/conda/compiler_compat _configtest.o -o _configtest
#       success!
#       removing: _configtest.c _configtest.o _configtest.o.d _configtest
#       C compiler: gcc -pthread -B /opt/conda/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/conda/include -fPIC -O2 -isystem /opt/conda/include -fPIC
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/opt/conda/include/python3.10 -c'
#       gcc: _configtest.c
#       _configtest.c:1:5: warning: conflicting types for built-in function ‘exp’; expected ‘double(double)’ [-Wbuiltin-declaration-mismatch]
#           1 | int exp (void);
#             |     ^~~
#       _configtest.c:1:1: note: ‘exp’ is declared in header ‘<math.h>’
#         +++ |+#include <math.h>
#           1 | int exp (void);
#       gcc -pthread -B /opt/conda/compiler_compat _configtest.o -o _configtest
#       /opt/conda/compiler_compat/ld: _configtest.o: in function `main':
#       _configtest.c:(.text.startup+0x9): undefined reference to `exp'
#       collect2: error: ld returned 1 exit status
#       failure.
#       removing: _configtest.c _configtest.o _configtest.o.d
#       C compiler: gcc -pthread -B /opt/conda/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/conda/include -fPIC -O2 -isystem /opt/conda/include -fPIC
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/opt/conda/include/python3.10 -c'
#       gcc: _configtest.c
#       _configtest.c:1:5: warning: conflicting types for built-in function ‘exp’; expected ‘double(double)’ [-Wbuiltin-declaration-mismatch]
#           1 | int exp (void);
#             |     ^~~
#       _configtest.c:1:1: note: ‘exp’ is declared in header ‘<math.h>’
#         +++ |+#include <math.h>
#           1 | int exp (void);
#       gcc -pthread -B /opt/conda/compiler_compat _configtest.o -lm -o _configtest
#       success!
#       removing: _configtest.c _configtest.o _configtest.o.d _configtest
#       creating build/src.linux-x86_64-3.1/numpy/core
#       creating build/src.linux-x86_64-3.1/numpy/core/src
#       creating build/src.linux-x86_64-3.1/numpy/core/src/npymath
#       conv_template:> build/src.linux-x86_64-3.1/numpy/core/src/npymath/npy_math_internal.h
#         adding 'build/src.linux-x86_64-3.1/numpy/core/src/npymath' to include_dirs.
#       conv_template:> build/src.linux-x86_64-3.1/numpy/core/src/npymath/ieee754.c
#       conv_template:> build/src.linux-x86_64-3.1/numpy/core/src/npymath/npy_math_complex.c
#       None - nothing done with h_files = ['build/src.linux-x86_64-3.1/numpy/core/src/npymath/npy_math_internal.h']
#       building library "npysort" sources
#       creating build/src.linux-x86_64-3.1/numpy/core/src/common
#       conv_template:> build/src.linux-x86_64-3.1/numpy/core/src/common/npy_sort.h
#         adding 'build/src.linux-x86_64-3.1/numpy/core/src/common' to include_dirs.
#       creating build/src.linux-x86_64-3.1/numpy/core/src/npysort
#       conv_template:> build/src.linux-x86_64-3.1/numpy/core/src/npysort/quicksort.c
#       conv_template:> build/src.linux-x86_64-3.1/numpy/core/src/npysort/mergesort.c
#       conv_template:> build/src.linux-x86_64-3.1/numpy/core/src/npysort/timsort.c
#       conv_template:> build/src.linux-x86_64-3.1/numpy/core/src/npysort/heapsort.c
#       conv_template:> build/src.linux-x86_64-3.1/numpy/core/src/npysort/radixsort.c
#       conv_template:> build/src.linux-x86_64-3.1/numpy/core/src/common/npy_partition.h
#       conv_template:> build/src.linux-x86_64-3.1/numpy/core/src/npysort/selection.c
#       conv_template:> build/src.linux-x86_64-3.1/numpy/core/src/common/npy_binsearch.h
#       conv_template:> build/src.linux-x86_64-3.1/numpy/core/src/npysort/binsearch.c
#       None - nothing done with h_files = ['build/src.linux-x86_64-3.1/numpy/core/src/common/npy_sort.h', 'build/src.linux-x86_64-3.1/numpy/core/src/common/npy_partition.h', 'build/src.linux-x86_64-3.1/numpy/core/src/common/npy_binsearch.h']
#       building extension "numpy.core._dummy" sources
#       Generating build/src.linux-x86_64-3.1/numpy/core/include/numpy/config.h
#       C compiler: gcc -pthread -B /opt/conda/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/conda/include -fPIC -O2 -isystem /opt/conda/include -fPIC
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/opt/conda/include/python3.10 -c'
#       gcc: _configtest.c
#       success!
#       removing: _configtest.c _configtest.o _configtest.o.d
#       C compiler: gcc -pthread -B /opt/conda/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/conda/include -fPIC -O2 -isystem /opt/conda/include -fPIC
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/opt/conda/include/python3.10 -c'
#       gcc: _configtest.c
#       success!
#       removing: _configtest.c _configtest.o _configtest.o.d
#       C compiler: gcc -pthread -B /opt/conda/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/conda/include -fPIC -O2 -isystem /opt/conda/include -fPIC
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/opt/conda/include/python3.10 -c'
#       gcc: _configtest.c
#       _configtest.c:1:10: fatal error: sys/endian.h: No such file or directory
#           1 | #include <sys/endian.h>
#             |          ^~~~~~~~~~~~~~
#       compilation terminated.
#       failure.
#       removing: _configtest.c _configtest.o
#       C compiler: gcc -pthread -B /opt/conda/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/conda/include -fPIC -O2 -isystem /opt/conda/include -fPIC
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/opt/conda/include/python3.10 -c'
#       gcc: _configtest.c
#       success!
#       removing: _configtest.c _configtest.o _configtest.o.d
#       C compiler: gcc -pthread -B /opt/conda/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/conda/include -fPIC -O2 -isystem /opt/conda/include -fPIC
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/opt/conda/include/python3.10 -c'
#       gcc: _configtest.c
#       success!
#       removing: _configtest.c _configtest.o _configtest.o.d
#       C compiler: gcc -pthread -B /opt/conda/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/conda/include -fPIC -O2 -isystem /opt/conda/include -fPIC
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/opt/conda/include/python3.10 -c'
#       gcc: _configtest.c
#       success!
#       removing: _configtest.c _configtest.o _configtest.o.d
#       C compiler: gcc -pthread -B /opt/conda/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/conda/include -fPIC -O2 -isystem /opt/conda/include -fPIC
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/opt/conda/include/python3.10 -c'
#       gcc: _configtest.c
#       success!
#       removing: _configtest.c _configtest.o _configtest.o.d
#       C compiler: gcc -pthread -B /opt/conda/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/conda/include -fPIC -O2 -isystem /opt/conda/include -fPIC
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/opt/conda/include/python3.10 -c'
#       gcc: _configtest.c
#       _configtest.c: In function ‘main’:
#       _configtest.c:5:16: warning: variable ‘test_array’ set but not used [-Wunused-but-set-variable]
#           5 |     static int test_array [1 - 2 * !(((long) (sizeof (npy_check_sizeof_type))) >= 0)];
#             |                ^~~~~~~~~~
#       removing: _configtest.c _configtest.o _configtest.o.d
#       C compiler: gcc -pthread -B /opt/conda/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/conda/include -fPIC -O2 -isystem /opt/conda/include -fPIC
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/opt/conda/include/python3.10 -c'
#       gcc: _configtest.c
#       _configtest.c: In function ‘main’:
#       _configtest.c:5:16: warning: variable ‘test_array’ set but not used [-Wunused-but-set-variable]
#           5 |     static int test_array [1 - 2 * !(((long) (sizeof (npy_check_sizeof_type))) == 4)];
#             |                ^~~~~~~~~~
#       removing: _configtest.c _configtest.o _configtest.o.d
#       C compiler: gcc -pthread -B /opt/conda/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/conda/include -fPIC -O2 -isystem /opt/conda/include -fPIC
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/opt/conda/include/python3.10 -c'
#       gcc: _configtest.c
#       _configtest.c: In function ‘main’:
#       _configtest.c:5:16: warning: variable ‘test_array’ set but not used [-Wunused-but-set-variable]
#           5 |     static int test_array [1 - 2 * !(((long) (sizeof (npy_check_sizeof_type))) >= 0)];
#             |                ^~~~~~~~~~
#       removing: _configtest.c _configtest.o _configtest.o.d
#       C compiler: gcc -pthread -B /opt/conda/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/conda/include -fPIC -O2 -isystem /opt/conda/include -fPIC
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/opt/conda/include/python3.10 -c'
#       gcc: _configtest.c
#       _configtest.c: In function ‘main’:
#       _configtest.c:5:16: warning: variable ‘test_array’ set but not used [-Wunused-but-set-variable]
#           5 |     static int test_array [1 - 2 * !(((long) (sizeof (npy_check_sizeof_type))) == 8)];
#             |                ^~~~~~~~~~
#       removing: _configtest.c _configtest.o _configtest.o.d
#       C compiler: gcc -pthread -B /opt/conda/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/conda/include -fPIC -O2 -isystem /opt/conda/include -fPIC
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/opt/conda/include/python3.10 -c'
#       gcc: _configtest.c
#       success!
#       removing: _configtest.c _configtest.o _configtest.o.d
#       C compiler: gcc -pthread -B /opt/conda/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/conda/include -fPIC -O2 -isystem /opt/conda/include -fPIC
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/opt/conda/include/python3.10 -c'
#       gcc: _configtest.c
#       _configtest.c: In function ‘main’:
#       _configtest.c:5:16: warning: variable ‘test_array’ set but not used [-Wunused-but-set-variable]
#           5 |     static int test_array [1 - 2 * !(((long) (sizeof (npy_check_sizeof_type))) >= 0)];
#             |                ^~~~~~~~~~
#       removing: _configtest.c _configtest.o _configtest.o.d
#       C compiler: gcc -pthread -B /opt/conda/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/conda/include -fPIC -O2 -isystem /opt/conda/include -fPIC
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/opt/conda/include/python3.10 -c'
#       gcc: _configtest.c
#       _configtest.c: In function ‘main’:
#       _configtest.c:5:16: warning: variable ‘test_array’ set but not used [-Wunused-but-set-variable]
#           5 |     static int test_array [1 - 2 * !(((long) (sizeof (npy_check_sizeof_type))) == 8)];
#             |                ^~~~~~~~~~
#       removing: _configtest.c _configtest.o _configtest.o.d
#       C compiler: gcc -pthread -B /opt/conda/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/conda/include -fPIC -O2 -isystem /opt/conda/include -fPIC
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/opt/conda/include/python3.10 -c'
#       gcc: _configtest.c
#       _configtest.c: In function ‘main’:
#       _configtest.c:5:16: warning: variable ‘test_array’ set but not used [-Wunused-but-set-variable]
#           5 |     static int test_array [1 - 2 * !(((long) (sizeof (npy_check_sizeof_type))) >= 0)];
#             |                ^~~~~~~~~~
#       removing: _configtest.c _configtest.o _configtest.o.d
#       C compiler: gcc -pthread -B /opt/conda/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/conda/include -fPIC -O2 -isystem /opt/conda/include -fPIC
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/opt/conda/include/python3.10 -c'
#       gcc: _configtest.c
#       _configtest.c: In function ‘main’:
#       _configtest.c:5:16: warning: variable ‘test_array’ set but not used [-Wunused-but-set-variable]
#           5 |     static int test_array [1 - 2 * !(((long) (sizeof (npy_check_sizeof_type))) == 16)];
#             |                ^~~~~~~~~~
#       removing: _configtest.c _configtest.o _configtest.o.d
#       C compiler: gcc -pthread -B /opt/conda/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/conda/include -fPIC -O2 -isystem /opt/conda/include -fPIC
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/opt/conda/include/python3.10 -c'
#       gcc: _configtest.c
#       _configtest.c: In function ‘main’:
#       _configtest.c:7:12: error: ‘SIZEOF_LONGDOUBLE’ undeclared (first use in this function); did you mean ‘SIZEOF_LONG_DOUBLE’?
#           7 |     (void) SIZEOF_LONGDOUBLE;
#             |            ^~~~~~~~~~~~~~~~~
#             |            SIZEOF_LONG_DOUBLE
#       _configtest.c:7:12: note: each undeclared identifier is reported only once for each function it appears in
#       failure.
#       removing: _configtest.c _configtest.o
#       C compiler: gcc -pthread -B /opt/conda/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/conda/include -fPIC -O2 -isystem /opt/conda/include -fPIC
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/opt/conda/include/python3.10 -c'
#       gcc: _configtest.c
#       _configtest.c: In function ‘main’:
#       _configtest.c:5:16: warning: variable ‘test_array’ set but not used [-Wunused-but-set-variable]
#           5 |     static int test_array [1 - 2 * !(((long) (sizeof (npy_check_sizeof_type))) >= 0)];
#             |                ^~~~~~~~~~
#       removing: _configtest.c _configtest.o _configtest.o.d
#       C compiler: gcc -pthread -B /opt/conda/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/conda/include -fPIC -O2 -isystem /opt/conda/include -fPIC
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/opt/conda/include/python3.10 -c'
#       gcc: _configtest.c
#       _configtest.c: In function ‘main’:
#       _configtest.c:5:16: warning: variable ‘test_array’ set but not used [-Wunused-but-set-variable]
#           5 |     static int test_array [1 - 2 * !(((long) (sizeof (npy_check_sizeof_type))) == 16)];
#             |                ^~~~~~~~~~
#       removing: _configtest.c _configtest.o _configtest.o.d
#       C compiler: gcc -pthread -B /opt/conda/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/conda/include -fPIC -O2 -isystem /opt/conda/include -fPIC
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/opt/conda/include/python3.10 -c'
#       gcc: _configtest.c
#       _configtest.c: In function ‘main’:
#       _configtest.c:5:16: warning: variable ‘test_array’ set but not used [-Wunused-but-set-variable]
#           5 |     static int test_array [1 - 2 * !(((long) (sizeof (npy_check_sizeof_type))) >= 0)];
#             |                ^~~~~~~~~~
#       removing: _configtest.c _configtest.o _configtest.o.d
#       C compiler: gcc -pthread -B /opt/conda/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/conda/include -fPIC -O2 -isystem /opt/conda/include -fPIC
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/opt/conda/include/python3.10 -c'
#       gcc: _configtest.c
#       _configtest.c: In function ‘main’:
#       _configtest.c:5:16: warning: variable ‘test_array’ set but not used [-Wunused-but-set-variable]
#           5 |     static int test_array [1 - 2 * !(((long) (sizeof (npy_check_sizeof_type))) == 32)];
#             |                ^~~~~~~~~~
#       removing: _configtest.c _configtest.o _configtest.o.d
#       C compiler: gcc -pthread -B /opt/conda/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/conda/include -fPIC -O2 -isystem /opt/conda/include -fPIC
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/opt/conda/include/python3.10 -c'
#       gcc: _configtest.c
#       _configtest.c: In function ‘main’:
#       _configtest.c:7:16: warning: variable ‘test_array’ set but not used [-Wunused-but-set-variable]
#           7 |     static int test_array [1 - 2 * !(((long) (sizeof (npy_check_sizeof_type))) >= 0)];
#             |                ^~~~~~~~~~
#       removing: _configtest.c _configtest.o _configtest.o.d
#       C compiler: gcc -pthread -B /opt/conda/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/conda/include -fPIC -O2 -isystem /opt/conda/include -fPIC
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/opt/conda/include/python3.10 -c'
#       gcc: _configtest.c
#       _configtest.c: In function ‘main’:
#       _configtest.c:7:16: warning: variable ‘test_array’ set but not used [-Wunused-but-set-variable]
#           7 |     static int test_array [1 - 2 * !(((long) (sizeof (npy_check_sizeof_type))) == 8)];
#             |                ^~~~~~~~~~
#       removing: _configtest.c _configtest.o _configtest.o.d
#       C compiler: gcc -pthread -B /opt/conda/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/conda/include -fPIC -O2 -isystem /opt/conda/include -fPIC
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/opt/conda/include/python3.10 -c'
#       gcc: _configtest.c
#       _configtest.c: In function ‘main’:
#       _configtest.c:7:16: warning: variable ‘test_array’ set but not used [-Wunused-but-set-variable]
#           7 |     static int test_array [1 - 2 * !(((long) (sizeof (npy_check_sizeof_type))) >= 0)];
#             |                ^~~~~~~~~~
#       removing: _configtest.c _configtest.o _configtest.o.d
#       C compiler: gcc -pthread -B /opt/conda/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/conda/include -fPIC -O2 -isystem /opt/conda/include -fPIC
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/opt/conda/include/python3.10 -c'
#       gcc: _configtest.c
#       _configtest.c: In function ‘main’:
#       _configtest.c:7:16: warning: variable ‘test_array’ set but not used [-Wunused-but-set-variable]
#           7 |     static int test_array [1 - 2 * !(((long) (sizeof (npy_check_sizeof_type))) == 8)];
#             |                ^~~~~~~~~~
#       removing: _configtest.c _configtest.o _configtest.o.d
#       C compiler: gcc -pthread -B /opt/conda/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/conda/include -fPIC -O2 -isystem /opt/conda/include -fPIC
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/opt/conda/include/python3.10 -c'
#       gcc: _configtest.c
#       success!
#       removing: _configtest.c _configtest.o _configtest.o.d
#       C compiler: gcc -pthread -B /opt/conda/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/conda/include -fPIC -O2 -isystem /opt/conda/include -fPIC
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/opt/conda/include/python3.10 -c'
#       gcc: _configtest.c
#       _configtest.c: In function ‘main’:
#       _configtest.c:7:16: warning: variable ‘test_array’ set but not used [-Wunused-but-set-variable]
#           7 |     static int test_array [1 - 2 * !(((long) (sizeof (npy_check_sizeof_type))) >= 0)];
#             |                ^~~~~~~~~~
#       removing: _configtest.c _configtest.o _configtest.o.d
#       C compiler: gcc -pthread -B /opt/conda/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/conda/include -fPIC -O2 -isystem /opt/conda/include -fPIC
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/opt/conda/include/python3.10 -c'
#       gcc: _configtest.c
#       _configtest.c: In function ‘main’:
#       _configtest.c:7:16: warning: variable ‘test_array’ set but not used [-Wunused-but-set-variable]
#           7 |     static int test_array [1 - 2 * !(((long) (sizeof (npy_check_sizeof_type))) == 8)];
#             |                ^~~~~~~~~~
#       removing: _configtest.c _configtest.o _configtest.o.d
#       C compiler: gcc -pthread -B /opt/conda/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/conda/include -fPIC -O2 -isystem /opt/conda/include -fPIC
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/opt/conda/include/python3.10 -c'
#       gcc: _configtest.c
#       _configtest.c: In function ‘main’:
#       _configtest.c:5:16: warning: variable ‘test_array’ set but not used [-Wunused-but-set-variable]
#           5 |     static int test_array [1 - 2 * !(((long) (sizeof (npy_check_sizeof_type))) >= 0)];
#             |                ^~~~~~~~~~
#       removing: _configtest.c _configtest.o _configtest.o.d
#       C compiler: gcc -pthread -B /opt/conda/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/conda/include -fPIC -O2 -isystem /opt/conda/include -fPIC
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/opt/conda/include/python3.10 -c'
#       gcc: _configtest.c
#       _configtest.c: In function ‘main’:
#       _configtest.c:5:16: warning: variable ‘test_array’ set but not used [-Wunused-but-set-variable]
#           5 |     static int test_array [1 - 2 * !(((long) (sizeof (npy_check_sizeof_type))) == 8)];
#             |                ^~~~~~~~~~
#       removing: _configtest.c _configtest.o _configtest.o.d
#       C compiler: gcc -pthread -B /opt/conda/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/conda/include -fPIC -O2 -isystem /opt/conda/include -fPIC
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/opt/conda/include/python3.10 -c'
#       gcc: _configtest.c
#       success!
#       removing: _configtest.c _configtest.o _configtest.o.d
#       C compiler: gcc -pthread -B /opt/conda/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/conda/include -fPIC -O2 -isystem /opt/conda/include -fPIC
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/opt/conda/include/python3.10 -c'
#       gcc: _configtest.c
#       _configtest.c:1:5: warning: conflicting types for built-in function ‘exp’; expected ‘double(double)’ [-Wbuiltin-declaration-mismatch]
#           1 | int exp (void);
#             |     ^~~
#       _configtest.c:1:1: note: ‘exp’ is declared in header ‘<math.h>’
#         +++ |+#include <math.h>
#           1 | int exp (void);
#       gcc -pthread -B /opt/conda/compiler_compat _configtest.o -o _configtest
#       /opt/conda/compiler_compat/ld: _configtest.o: in function `main':
#       _configtest.c:(.text.startup+0x9): undefined reference to `exp'
#       collect2: error: ld returned 1 exit status
#       failure.
#       removing: _configtest.c _configtest.o _configtest.o.d
#       C compiler: gcc -pthread -B /opt/conda/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/conda/include -fPIC -O2 -isystem /opt/conda/include -fPIC
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/opt/conda/include/python3.10 -c'
#       gcc: _configtest.c
#       _configtest.c:1:5: warning: conflicting types for built-in function ‘exp’; expected ‘double(double)’ [-Wbuiltin-declaration-mismatch]
#           1 | int exp (void);
#             |     ^~~
#       _configtest.c:1:1: note: ‘exp’ is declared in header ‘<math.h>’
#         +++ |+#include <math.h>
#           1 | int exp (void);
#       gcc -pthread -B /opt/conda/compiler_compat _configtest.o -lm -o _configtest
#       success!
#       removing: _configtest.c _configtest.o _configtest.o.d _configtest
#       C compiler: gcc -pthread -B /opt/conda/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/conda/include -fPIC -O2 -isystem /opt/conda/include -fPIC
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/opt/conda/include/python3.10 -c'
#       gcc: _configtest.c
#       _configtest.c:1:5: warning: conflicting types for built-in function ‘sin’; expected ‘double(double)’ [-Wbuiltin-declaration-mismatch]
#           1 | int sin (void);
#             |     ^~~
#       _configtest.c:1:1: note: ‘sin’ is declared in header ‘<math.h>’
#         +++ |+#include <math.h>
#           1 | int sin (void);
#       _configtest.c:2:5: warning: conflicting types for built-in function ‘cos’; expected ‘double(double)’ [-Wbuiltin-declaration-mismatch]
#           2 | int cos (void);
#             |     ^~~
#       _configtest.c:2:5: note: ‘cos’ is declared in header ‘<math.h>’
#       _configtest.c:3:5: warning: conflicting types for built-in function ‘tan’; expected ‘double(double)’ [-Wbuiltin-declaration-mismatch]
#           3 | int tan (void);
#             |     ^~~
#       _configtest.c:3:5: note: ‘tan’ is declared in header ‘<math.h>’
#       _configtest.c:4:5: warning: conflicting types for built-in function ‘sinh’; expected ‘double(double)’ [-Wbuiltin-declaration-mismatch]
#           4 | int sinh (void);
#             |     ^~~~
#       _configtest.c:4:5: note: ‘sinh’ is declared in header ‘<math.h>’
#       _configtest.c:5:5: warning: conflicting types for built-in function ‘cosh’; expected ‘double(double)’ [-Wbuiltin-declaration-mismatch]
#           5 | int cosh (void);
#             |     ^~~~
#       _configtest.c:5:5: note: ‘cosh’ is declared in header ‘<math.h>’
#       _configtest.c:6:5: warning: conflicting types for built-in function ‘tanh’; expected ‘double(double)’ [-Wbuiltin-declaration-mismatch]
#           6 | int tanh (void);
#             |     ^~~~
#       _configtest.c:6:5: note: ‘tanh’ is declared in header ‘<math.h>’
#       _configtest.c:7:5: warning: conflicting types for built-in function ‘fabs’; expected ‘double(double)’ [-Wbuiltin-declaration-mismatch]
#           7 | int fabs (void);
#             |     ^~~~
#       _configtest.c:7:5: note: ‘fabs’ is declared in header ‘<math.h>’
#       _configtest.c:8:5: warning: conflicting types for built-in function ‘floor’; expected ‘double(double)’ [-Wbuiltin-declaration-mismatch]
#           8 | int floor (void);
#             |     ^~~~~
#       _configtest.c:8:5: note: ‘floor’ is declared in header ‘<math.h>’
#       _configtest.c:9:5: warning: conflicting types for built-in function ‘ceil’; expected ‘double(double)’ [-Wbuiltin-declaration-mismatch]
#           9 | int ceil (void);
#             |     ^~~~
#       _configtest.c:9:5: note: ‘ceil’ is declared in header ‘<math.h>’
#       _configtest.c:10:5: warning: conflicting types for built-in function ‘sqrt’; expected ‘double(double)’ [-Wbuiltin-declaration-mismatch]
#          10 | int sqrt (void);
#             |     ^~~~
#       _configtest.c:10:5: note: ‘sqrt’ is declared in header ‘<math.h>’
#       _configtest.c:11:5: warning: conflicting types for built-in function ‘log10’; expected ‘double(double)’ [-Wbuiltin-declaration-mismatch]
#          11 | int log10 (void);
#             |     ^~~~~
#       _configtest.c:11:5: note: ‘log10’ is declared in header ‘<math.h>’
#       _configtest.c:12:5: warning: conflicting types for built-in function ‘log’; expected ‘double(double)’ [-Wbuiltin-declaration-mismatch]
#          12 | int log (void);
#             |     ^~~
#       _configtest.c:12:5: note: ‘log’ is declared in header ‘<math.h>’
#       _configtest.c:13:5: warning: conflicting types for built-in function ‘exp’; expected ‘double(double)’ [-Wbuiltin-declaration-mismatch]
#          13 | int exp (void);
#             |     ^~~
#       _configtest.c:13:5: note: ‘exp’ is declared in header ‘<math.h>’
#       _configtest.c:14:5: warning: conflicting types for built-in function ‘asin’; expected ‘double(double)’ [-Wbuiltin-declaration-mismatch]
#          14 | int asin (void);
#             |     ^~~~
#       _configtest.c:14:5: note: ‘asin’ is declared in header ‘<math.h>’
#       _configtest.c:15:5: warning: conflicting types for built-in function ‘acos’; expected ‘double(double)’ [-Wbuiltin-declaration-mismatch]
#          15 | int acos (void);
#             |     ^~~~
#       _configtest.c:15:5: note: ‘acos’ is declared in header ‘<math.h>’
#       _configtest.c:16:5: warning: conflicting types for built-in function ‘atan’; expected ‘double(double)’ [-Wbuiltin-declaration-mismatch]
#          16 | int atan (void);
#             |     ^~~~
#       _configtest.c:16:5: note: ‘atan’ is declared in header ‘<math.h>’
#       _configtest.c:17:5: warning: conflicting types for built-in function ‘fmod’; expected ‘double(double,  double)’ [-Wbuiltin-declaration-mismatch]
#          17 | int fmod (void);
#             |     ^~~~
#       _configtest.c:17:5: note: ‘fmod’ is declared in header ‘<math.h>’
#       _configtest.c:18:5: warning: conflicting types for built-in function ‘modf’; expected ‘double(double,  double *)’ [-Wbuiltin-declaration-mismatch]
#          18 | int modf (void);
#             |     ^~~~
#       _configtest.c:18:5: note: ‘modf’ is declared in header ‘<math.h>’
#       _configtest.c:19:5: warning: conflicting types for built-in function ‘frexp’; expected ‘double(double,  int *)’ [-Wbuiltin-declaration-mismatch]
#          19 | int frexp (void);
#             |     ^~~~~
#       _configtest.c:19:5: note: ‘frexp’ is declared in header ‘<math.h>’
#       _configtest.c:20:5: warning: conflicting types for built-in function ‘ldexp’; expected ‘double(double,  int)’ [-Wbuiltin-declaration-mismatch]
#          20 | int ldexp (void);
#             |     ^~~~~
#       _configtest.c:20:5: note: ‘ldexp’ is declared in header ‘<math.h>’
#       gcc -pthread -B /opt/conda/compiler_compat _configtest.o -lm -o _configtest
#       success!
#       removing: _configtest.c _configtest.o _configtest.o.d _configtest
#       C compiler: gcc -pthread -B /opt/conda/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/conda/include -fPIC -O2 -isystem /opt/conda/include -fPIC
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/opt/conda/include/python3.10 -c'
#       gcc: _configtest.c
#       success!
#       removing: _configtest.c _configtest.o _configtest.o.d
#       C compiler: gcc -pthread -B /opt/conda/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/conda/include -fPIC -O2 -isystem /opt/conda/include -fPIC
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/opt/conda/include/python3.10 -c'
#       gcc: _configtest.c
#       success!
#       removing: _configtest.c _configtest.o _configtest.o.d
#       C compiler: gcc -pthread -B /opt/conda/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/conda/include -fPIC -O2 -isystem /opt/conda/include -fPIC
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/opt/conda/include/python3.10 -c'
#       gcc: _configtest.c
#       success!
#       removing: _configtest.c _configtest.o _configtest.o.d
#       C compiler: gcc -pthread -B /opt/conda/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/conda/include -fPIC -O2 -isystem /opt/conda/include -fPIC
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/opt/conda/include/python3.10 -c'
#       gcc: _configtest.c
#       success!
#       removing: _configtest.c _configtest.o _configtest.o.d
#       C compiler: gcc -pthread -B /opt/conda/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/conda/include -fPIC -O2 -isystem /opt/conda/include -fPIC
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/opt/conda/include/python3.10 -c'
#       gcc: _configtest.c
#       success!
#       removing: _configtest.c _configtest.o _configtest.o.d
#       C compiler: gcc -pthread -B /opt/conda/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/conda/include -fPIC -O2 -isystem /opt/conda/include -fPIC
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/opt/conda/include/python3.10 -c'
#       gcc: _configtest.c
#       success!
#       removing: _configtest.c _configtest.o _configtest.o.d
#       C compiler: gcc -pthread -B /opt/conda/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/conda/include -fPIC -O2 -isystem /opt/conda/include -fPIC
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/opt/conda/include/python3.10 -c'
#       gcc: _configtest.c
#       success!
#       removing: _configtest.c _configtest.o _configtest.o.d
#       C compiler: gcc -pthread -B /opt/conda/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/conda/include -fPIC -O2 -isystem /opt/conda/include -fPIC
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/opt/conda/include/python3.10 -c'
#       gcc: _configtest.c
#       success!
#       removing: _configtest.c _configtest.o _configtest.o.d
#       C compiler: gcc -pthread -B /opt/conda/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/conda/include -fPIC -O2 -isystem /opt/conda/include -fPIC
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/opt/conda/include/python3.10 -c'
#       gcc: _configtest.c
#       success!
#       removing: _configtest.c _configtest.o _configtest.o.d
#       C compiler: gcc -pthread -B /opt/conda/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/conda/include -fPIC -O2 -isystem /opt/conda/include -fPIC
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/opt/conda/include/python3.10 -c'
#       gcc: _configtest.c
#       _configtest.c:1:5: warning: conflicting types for built-in function ‘rint’; expected ‘double(double)’ [-Wbuiltin-declaration-mismatch]
#           1 | int rint (void);
#             |     ^~~~
#       _configtest.c:1:1: note: ‘rint’ is declared in header ‘<math.h>’
#         +++ |+#include <math.h>
#           1 | int rint (void);
#       _configtest.c:2:5: warning: conflicting types for built-in function ‘trunc’; expected ‘double(double)’ [-Wbuiltin-declaration-mismatch]
#           2 | int trunc (void);
#             |     ^~~~~
#       _configtest.c:2:5: note: ‘trunc’ is declared in header ‘<math.h>’
#       _configtest.c:3:5: warning: conflicting types for built-in function ‘exp2’; expected ‘double(double)’ [-Wbuiltin-declaration-mismatch]
#           3 | int exp2 (void);
#             |     ^~~~
#       _configtest.c:3:5: note: ‘exp2’ is declared in header ‘<math.h>’
#       _configtest.c:4:5: warning: conflicting types for built-in function ‘log2’; expected ‘double(double)’ [-Wbuiltin-declaration-mismatch]
#           4 | int log2 (void);
#             |     ^~~~
#       _configtest.c:4:5: note: ‘log2’ is declared in header ‘<math.h>’
#       _configtest.c:5:5: warning: conflicting types for built-in function ‘atan2’; expected ‘double(double,  double)’ [-Wbuiltin-declaration-mismatch]
#           5 | int atan2 (void);
#             |     ^~~~~
#       _configtest.c:5:5: note: ‘atan2’ is declared in header ‘<math.h>’
#       _configtest.c:6:5: warning: conflicting types for built-in function ‘pow’; expected ‘double(double,  double)’ [-Wbuiltin-declaration-mismatch]
#           6 | int pow (void);
#             |     ^~~
#       _configtest.c:6:5: note: ‘pow’ is declared in header ‘<math.h>’
#       _configtest.c:7:5: warning: conflicting types for built-in function ‘nextafter’; expected ‘double(double,  double)’ [-Wbuiltin-declaration-mismatch]
#           7 | int nextafter (void);
#             |     ^~~~~~~~~
#       _configtest.c:7:5: note: ‘nextafter’ is declared in header ‘<math.h>’
#       _configtest.c:10:5: warning: conflicting types for built-in function ‘cbrt’; expected ‘double(double)’ [-Wbuiltin-declaration-mismatch]
#          10 | int cbrt (void);
#             |     ^~~~
#       _configtest.c:10:5: note: ‘cbrt’ is declared in header ‘<math.h>’
#       gcc -pthread -B /opt/conda/compiler_compat _configtest.o -lm -o _configtest
#       success!
#       removing: _configtest.c _configtest.o _configtest.o.d _configtest
#       C compiler: gcc -pthread -B /opt/conda/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/conda/include -fPIC -O2 -isystem /opt/conda/include -fPIC
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/opt/conda/include/python3.10 -c'
#       gcc: _configtest.c
#       gcc -pthread -B /opt/conda/compiler_compat _configtest.o -o _configtest
#       success!
#       removing: _configtest.c _configtest.o _configtest.o.d _configtest
#       C compiler: gcc -pthread -B /opt/conda/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/conda/include -fPIC -O2 -isystem /opt/conda/include -fPIC
#
#       compile options: '-Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/opt/conda/include/python3.10 -c'
#       gcc: _configtest.c
#       gcc -pthread -B /opt/conda/compiler_compat _configtest.o -o _configtest
#       success!
#       removing: _configtest.c _configtest.o _configtest.o.d _configtest
# ...
#       In file included from /opt/conda/include/python3.10/Python.h:77,
#                        from numpy/core/src/multiarray/scalartypes.c.src:3:
#       /opt/conda/include/python3.10/pyhash.h:10:23: note: declared here
#          10 | PyAPI_FUNC(Py_hash_t) _Py_HashDouble(PyObject *, double);
#             |                       ^~~~~~~~~~~~~~
#       numpy/core/src/multiarray/scalartypes.c.src: In function ‘longdouble_arrtype_hash’:
#       numpy/core/src/multiarray/scalartypes.c.src:3311:27: error: incompatible type for argument 1 of ‘_Py_HashDouble’
#        3311 |     return _Py_HashDouble((double) ((Py@name@ScalarObject *)obj)->obval);
#             |                           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#             |                           |
#             |                           double
#       In file included from /opt/conda/include/python3.10/Python.h:77,
#                        from numpy/core/src/multiarray/scalartypes.c.src:3:
#       /opt/conda/include/python3.10/pyhash.h:10:38: note: expected ‘PyObject *’ {aka ‘struct _object *’} but argument is of type ‘double’
#          10 | PyAPI_FUNC(Py_hash_t) _Py_HashDouble(PyObject *, double);
#             |                                      ^~~~~~~~~~
#       numpy/core/src/multiarray/scalartypes.c.src:3311:12: error: too few arguments to function ‘_Py_HashDouble’
#        3311 |     return _Py_HashDouble((double) ((Py@name@ScalarObject *)obj)->obval);
#             |            ^~~~~~~~~~~~~~
#       In file included from /opt/conda/include/python3.10/Python.h:77,
#                        from numpy/core/src/multiarray/scalartypes.c.src:3:
#       /opt/conda/include/python3.10/pyhash.h:10:23: note: declared here
#          10 | PyAPI_FUNC(Py_hash_t) _Py_HashDouble(PyObject *, double);
#             |                       ^~~~~~~~~~~~~~
#       numpy/core/src/multiarray/scalartypes.c.src: In function ‘clongdouble_arrtype_hash’:
#       numpy/core/src/multiarray/scalartypes.c.src:3319:31: error: incompatible type for argument 1 of ‘_Py_HashDouble’
#        3319 |     hashreal = _Py_HashDouble((double)
#             |                               ^~~~~~~~
#             |                               |
#             |                               double
#        3320 |             (((PyC@name@ScalarObject *)obj)->obval).real);
#             |             ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#       In file included from /opt/conda/include/python3.10/Python.h:77,
#                        from numpy/core/src/multiarray/scalartypes.c.src:3:
#       /opt/conda/include/python3.10/pyhash.h:10:38: note: expected ‘PyObject *’ {aka ‘struct _object *’} but argument is of type ‘double’
#          10 | PyAPI_FUNC(Py_hash_t) _Py_HashDouble(PyObject *, double);
#             |                                      ^~~~~~~~~~
#       numpy/core/src/multiarray/scalartypes.c.src:3319:16: error: too few arguments to function ‘_Py_HashDouble’
#        3319 |     hashreal = _Py_HashDouble((double)
#             |                ^~~~~~~~~~~~~~
#       In file included from /opt/conda/include/python3.10/Python.h:77,
#                        from numpy/core/src/multiarray/scalartypes.c.src:3:
#       /opt/conda/include/python3.10/pyhash.h:10:23: note: declared here
#          10 | PyAPI_FUNC(Py_hash_t) _Py_HashDouble(PyObject *, double);
#             |                       ^~~~~~~~~~~~~~
#       numpy/core/src/multiarray/scalartypes.c.src:3325:31: error: incompatible type for argument 1 of ‘_Py_HashDouble’
#        3325 |     hashimag = _Py_HashDouble((double)
#             |                               ^~~~~~~~
#             |                               |
#             |                               double
#        3326 |             (((PyC@name@ScalarObject *)obj)->obval).imag);
#             |             ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#       In file included from /opt/conda/include/python3.10/Python.h:77,
#                        from numpy/core/src/multiarray/scalartypes.c.src:3:
#       /opt/conda/include/python3.10/pyhash.h:10:38: note: expected ‘PyObject *’ {aka ‘struct _object *’} but argument is of type ‘double’
#          10 | PyAPI_FUNC(Py_hash_t) _Py_HashDouble(PyObject *, double);
#             |                                      ^~~~~~~~~~
#       numpy/core/src/multiarray/scalartypes.c.src:3325:16: error: too few arguments to function ‘_Py_HashDouble’
#        3325 |     hashimag = _Py_HashDouble((double)
#             |                ^~~~~~~~~~~~~~
#       In file included from /opt/conda/include/python3.10/Python.h:77,
#                        from numpy/core/src/multiarray/scalartypes.c.src:3:
#       /opt/conda/include/python3.10/pyhash.h:10:23: note: declared here
#          10 | PyAPI_FUNC(Py_hash_t) _Py_HashDouble(PyObject *, double);
#             |                       ^~~~~~~~~~~~~~
#       numpy/core/src/multiarray/scalartypes.c.src: In function ‘half_arrtype_hash’:
#       numpy/core/src/multiarray/scalartypes.c.src:3341:27: error: incompatible type for argument 1 of ‘_Py_HashDouble’
#        3341 |     return _Py_HashDouble(npy_half_to_double(((PyHalfScalarObject *)obj)->obval));
#             |                           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#             |                           |
#             |                           double
#       In file included from /opt/conda/include/python3.10/Python.h:77,
#                        from numpy/core/src/multiarray/scalartypes.c.src:3:
#       /opt/conda/include/python3.10/pyhash.h:10:38: note: expected ‘PyObject *’ {aka ‘struct _object *’} but argument is of type ‘double’
#          10 | PyAPI_FUNC(Py_hash_t) _Py_HashDouble(PyObject *, double);
#             |                                      ^~~~~~~~~~
#       numpy/core/src/multiarray/scalartypes.c.src:3341:12: error: too few arguments to function ‘_Py_HashDouble’
#        3341 |     return _Py_HashDouble(npy_half_to_double(((PyHalfScalarObject *)obj)->obval));
#             |            ^~~~~~~~~~~~~~
#       In file included from /opt/conda/include/python3.10/Python.h:77,
#                        from numpy/core/src/multiarray/scalartypes.c.src:3:
#       /opt/conda/include/python3.10/pyhash.h:10:23: note: declared here
#          10 | PyAPI_FUNC(Py_hash_t) _Py_HashDouble(PyObject *, double);
#             |                       ^~~~~~~~~~~~~~
#       numpy/core/src/multiarray/scalartypes.c.src: In function ‘longdouble_arrtype_hash’:
#       numpy/core/src/multiarray/scalartypes.c.src:3312:1: warning: control reaches end of non-void function [-Wreturn-type]
#        3312 | }
#             | ^
#       numpy/core/src/multiarray/scalartypes.c.src: In function ‘float_arrtype_hash’:
#       numpy/core/src/multiarray/scalartypes.c.src:3312:1: warning: control reaches end of non-void function [-Wreturn-type]
#        3312 | }
#             | ^
#       numpy/core/src/multiarray/scalartypes.c.src: In function ‘half_arrtype_hash’:
#       numpy/core/src/multiarray/scalartypes.c.src:3342:1: warning: control reaches end of non-void function [-Wreturn-type]
#        3342 | }
#             | ^
#       gcc: numpy/core/src/multiarray/vdot.c
#       gcc: numpy/core/src/multiarray/refcount.c
#       gcc: numpy/core/src/umath/umathmodule.c
#       gcc: numpy/core/src/multiarray/nditer_pywrap.c
#       gcc: numpy/core/src/umath/reduction.c
#       gcc: numpy/core/src/multiarray/sequence.c
#       gcc: numpy/core/src/multiarray/shape.c
#       gcc: build/src.linux-x86_64-3.1/numpy/core/src/umath/loops.c
#       gcc: build/src.linux-x86_64-3.1/numpy/core/src/umath/clip.c
#       gcc: numpy/core/src/multiarray/scalarapi.c
#       numpy/core/src/umath/loops.c.src: In function ‘PyUFunc_On_Om’:
#       numpy/core/src/umath/loops.c.src:506:9: warning: ‘PyEval_CallObjectWithKeywords’ is deprecated [-Wdeprecated-declarations]
#         506 |         result = PyEval_CallObject(tocall, arglist);
#             |         ^~~~~~
#       In file included from /opt/conda/include/python3.10/Python.h:130,
#                        from numpy/core/src/umath/loops.c.src:7:
#       /opt/conda/include/python3.10/ceval.h:17:43: note: declared here
#          17 | Py_DEPRECATED(3.9) PyAPI_FUNC(PyObject *) PyEval_CallObjectWithKeywords(
#             |                                           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#       numpy/core/src/multiarray/scalarapi.c: In function ‘scalar_value’:
#       numpy/core/src/multiarray/scalarapi.c:74:13: warning: ‘PyUnicode_AsUnicode’ is deprecated [-Wdeprecated-declarations]
#          74 |             return (void *)PyUnicode_AS_DATA(scalar);
#             |             ^~~~~~
#       In file included from /opt/conda/include/python3.10/unicodeobject.h:1046,
#                        from /opt/conda/include/python3.10/Python.h:83,
#                        from numpy/core/src/multiarray/scalarapi.c:2:
#       /opt/conda/include/python3.10/cpython/unicodeobject.h:580:45: note: declared here
#         580 | Py_DEPRECATED(3.3) PyAPI_FUNC(Py_UNICODE *) PyUnicode_AsUnicode(
#             |                                             ^~~~~~~~~~~~~~~~~~~
#       numpy/core/src/multiarray/scalarapi.c:135:13: warning: ‘PyUnicode_AsUnicode’ is deprecated [-Wdeprecated-declarations]
#         135 |             return (void *)PyUnicode_AS_DATA(scalar);
#             |             ^~~~~~
#       In file included from /opt/conda/include/python3.10/unicodeobject.h:1046,
#                        from /opt/conda/include/python3.10/Python.h:83,
#                        from numpy/core/src/multiarray/scalarapi.c:2:
#       /opt/conda/include/python3.10/cpython/unicodeobject.h:580:45: note: declared here
#         580 | Py_DEPRECATED(3.3) PyAPI_FUNC(Py_UNICODE *) PyUnicode_AsUnicode(
#             |                                             ^~~~~~~~~~~~~~~~~~~
#       numpy/core/src/multiarray/scalarapi.c: In function ‘PyArray_DescrFromScalar’:
#       numpy/core/src/multiarray/scalarapi.c:574:13: warning: ‘_PyUnicode_get_wstr_length’ is deprecated [-Wdeprecated-declarations]
#         574 |             descr->elsize = PyUnicode_GET_DATA_SIZE(sc);
#             |             ^~~~~
#       In file included from /opt/conda/include/python3.10/unicodeobject.h:1046,
#                        from /opt/conda/include/python3.10/Python.h:83,
#                        from numpy/core/src/multiarray/scalarapi.c:2:
#       /opt/conda/include/python3.10/cpython/unicodeobject.h:446:26: note: declared here
#         446 | static inline Py_ssize_t _PyUnicode_get_wstr_length(PyObject *op) {
#             |                          ^~~~~~~~~~~~~~~~~~~~~~~~~~
#       numpy/core/src/multiarray/scalarapi.c:574:13: warning: ‘PyUnicode_AsUnicode’ is deprecated [-Wdeprecated-declarations]
#         574 |             descr->elsize = PyUnicode_GET_DATA_SIZE(sc);
#             |             ^~~~~
#       In file included from /opt/conda/include/python3.10/unicodeobject.h:1046,
#                        from /opt/conda/include/python3.10/Python.h:83,
#                        from numpy/core/src/multiarray/scalarapi.c:2:
#       /opt/conda/include/python3.10/cpython/unicodeobject.h:580:45: note: declared here
#         580 | Py_DEPRECATED(3.3) PyAPI_FUNC(Py_UNICODE *) PyUnicode_AsUnicode(
#             |                                             ^~~~~~~~~~~~~~~~~~~
#       numpy/core/src/multiarray/scalarapi.c:574:13: warning: ‘_PyUnicode_get_wstr_length’ is deprecated [-Wdeprecated-declarations]
#         574 |             descr->elsize = PyUnicode_GET_DATA_SIZE(sc);
#             |             ^~~~~
#       In file included from /opt/conda/include/python3.10/unicodeobject.h:1046,
#                        from /opt/conda/include/python3.10/Python.h:83,
#                        from numpy/core/src/multiarray/scalarapi.c:2:
#       /opt/conda/include/python3.10/cpython/unicodeobject.h:446:26: note: declared here
#         446 | static inline Py_ssize_t _PyUnicode_get_wstr_length(PyObject *op) {
#             |                          ^~~~~~~~~~~~~~~~~~~~~~~~~~
#       gcc: numpy/core/src/umath/ufunc_type_resolution.c
#       gcc: numpy/core/src/umath/ufunc_object.c
#       gcc: numpy/core/src/umath/override.c
#       gcc: numpy/core/src/npymath/npy_math.c
#       gcc: build/src.linux-x86_64-3.1/numpy/core/src/npymath/ieee754.c
#       gcc: build/src.linux-x86_64-3.1/numpy/core/src/npymath/npy_math_complex.c
#       gcc: numpy/core/src/npymath/halffloat.c
#       gcc: numpy/core/src/common/array_assign.c
#       gcc: numpy/core/src/common/mem_overlap.c
#       gcc: numpy/core/src/umath/extobj.c
#       gcc: numpy/core/src/umath/cpuid.c
#       gcc: build/src.linux-x86_64-3.1/numpy/core/src/umath/scalarmath.c
#       gcc: numpy/core/src/common/npy_longdouble.c
#       gcc: numpy/core/src/common/ucsnarrow.c
#       numpy/core/src/common/ucsnarrow.c: In function ‘PyUnicode_FromUCS4’:
#       numpy/core/src/common/ucsnarrow.c:139:9: warning: ‘PyUnicode_FromUnicode’ is deprecated [-Wdeprecated-declarations]
#         139 |         ret = (PyUnicodeObject *)PyUnicode_FromUnicode((Py_UNICODE*)buf,
#             |         ^~~
#       In file included from /opt/conda/include/python3.10/unicodeobject.h:1046,
#                        from /opt/conda/include/python3.10/Python.h:83,
#                        from numpy/core/src/common/ucsnarrow.c:4:
#       /opt/conda/include/python3.10/cpython/unicodeobject.h:551:42: note: declared here
#         551 | Py_DEPRECATED(3.3) PyAPI_FUNC(PyObject*) PyUnicode_FromUnicode(
#             |                                          ^~~~~~~~~~~~~~~~~~~~~
#       gcc: numpy/core/src/common/ufunc_override.c
#       gcc: numpy/core/src/common/numpyos.c
#       gcc: numpy/core/src/common/cblasfuncs.c
#       gcc: numpy/core/src/common/python_xerbla.c
#       gcc: numpy/core/src/multiarray/mapping.c
#       gcc: numpy/core/src/multiarray/methods.c
#       gcc: build/src.linux-x86_64-3.1/numpy/core/src/umath/matmul.c
#       error: Command "gcc -pthread -B /opt/conda/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/conda/include -fPIC -O2 -isystem /opt/conda/include -fPIC -DNPY_INTERNAL_BUILD=1 -DHAVE_NPY_CONFIG_H=1 -D_FILE_OFFSET_BITS=64 -D_LARGEFILE_SOURCE=1 -D_LARGEFILE64_SOURCE=1 -DSCIPY_MKL_H -DHAVE_CBLAS -I/usr/local/include -I/usr/include -I/opt/conda/include -Ibuild/src.linux-x86_64-3.1/numpy/core/src/umath -Ibuild/src.linux-x86_64-3.1/numpy/core/src/npymath -Ibuild/src.linux-x86_64-3.1/numpy/core/src/common -Inumpy/core/include -Ibuild/src.linux-x86_64-3.1/numpy/core/include/numpy -Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -I/opt/conda/include/python3.10 -Ibuild/src.linux-x86_64-3.1/numpy/core/src/common -Ibuild/src.linux-x86_64-3.1/numpy/core/src/npymath -Ibuild/src.linux-x86_64-3.1/numpy/core/src/common -Ibuild/src.linux-x86_64-3.1/numpy/core/src/npymath -c build/src.linux-x86_64-3.1/numpy/core/src/multiarray/scalartypes.c -o build/temp.linux-x86_64-3.10/build/src.linux-x86_64-3.1/numpy/core/src/multiarray/scalartypes.o -MMD -MF build/temp.linux-x86_64-3.10/build/src.linux-x86_64-3.1/numpy/core/src/multiarray/scalartypes.o.d" failed with exit status 1
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for numpy
#   Running setup.py clean for numpy
#   error: subprocess-exited-with-error
#
#   × python setup.py clean did not run successfully.
#   │ exit code: 1
#   ╰─> [10 lines of output]
#       Running from numpy source directory.
#
#       `setup.py clean` is not supported, use one of the following instead:
#
#         - `git clean -xdf` (cleans all files)
#         - `git clean -Xdf` (cleans all versioned files, doesn't touch
#                             files that aren't checked into the git repo)
#
#       Add `--force` to your command to use it anyway if you must (unsupported).
#
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed cleaning build dir for numpy
# Failed to build numpy
# ERROR: Could not build wheels for numpy, which is required to install pyproject.toml-based projects

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

import re, spacy

from time import time 

from sklearn.model_selection import train_test_split

from tensorflow.keras.preprocessing.text import Tokenizer 
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.layers import Input, Embedding, LSTM, Concatenate, TimeDistributed, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping

import warnings
warnings.filterwarnings('ignore')
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")

# %%
data = pd.read_csv("/kaggle/input/bengali-text-summarization/text_summarization.csv")
data.head()
# Out:
#      category                                            summary  \
# 0  technology         অ্যাপসে মিলবে ঢাকাসহ তিন জেলা আদালতের তথ্য
# 1  bangladesh  বিজ্ঞান ও প্রকৌশলে মার্কিন সর্বোচ্চ সম্মাননা...
# 2  bangladesh  বিকল্প শিশুখাদ্য গ্রহণে শিশুর মৃত্যু হলে শাস্ত...
# 3  bangladesh       ট্রেনে কাটা পড়ে সাবেক সিভিল সার্জনের মৃত্যু
# 4  bangladesh  যাত্রাবাড়ীতে চুলা জ্বালাতে গিয়ে দুই কর্মচারী ...
#
#                                                 text
# 0  ঢাকা মহানগর ও ঢাকা জেলা আদালত, কিশোরগঞ্জ ও রাঙ...
# 1  যুক্তরাষ্ট্রে বিজ্ঞান ও প্রকৌশলে পেশা শুরুর প...
# 2  বিকল্প শিশুখাদ্য ও বাণিজ্যিকভাবে উত্পাদিত শিশু...
# 3  বগুড়ার আদমদীঘির সান্তাহারে গতকাল শনিবার ট্রেন...
# 4  যাত্রাবাড়ীর একটি রেস্তোরাঁয় গতকাল বুধবার ভোর...

# %%
print("Shape of the dataset is :", data.shape)
# Out:
# Shape of the dataset is : (80331, 3)

# %%
data.head(10)
# Out:
#      category                                            summary  \
# 0  technology         অ্যাপসে মিলবে ঢাকাসহ তিন জেলা আদালতের তথ্য
# 1  bangladesh  বিজ্ঞান ও প্রকৌশলে মার্কিন সর্বোচ্চ সম্মাননা...
# 2  bangladesh  বিকল্প শিশুখাদ্য গ্রহণে শিশুর মৃত্যু হলে শাস্ত...
# 3  bangladesh       ট্রেনে কাটা পড়ে সাবেক সিভিল সার্জনের মৃত্যু
# 4  bangladesh  যাত্রাবাড়ীতে চুলা জ্বালাতে গিয়ে দুই কর্মচারী ...
# 5  bangladesh   ‘বাল্যবিবাহমুক্ত’ জেলা ঘোষণা চলছে নিয়ম না মেনেই
# 6      sports  পাকিস্তানি ক্রিকেটারদের দুটির বেশি টি-টোয়েন্টি...
# 7  bangladesh  চাটখিল উপজেলা ভাইস চেয়ারম্যান সন্ত্রাসী হামলার...
# 8  bangladesh  ব্যবসায়ীদের চাপে জরিমানা কমাতে বাধ্য হলেন বিচারক
# 9  bangladesh       নাইকো দুর্নীতি মামলায় আপিল করলেন খালেদা জিয়া
#
#                                                 text
# 0  ঢাকা মহানগর ও ঢাকা জেলা আদালত, কিশোরগঞ্জ ও রাঙ...
# 1  যুক্তরাষ্ট্রে বিজ্ঞান ও প্রকৌশলে পেশা শুরুর প...
# 2  বিকল্প শিশুখাদ্য ও বাণিজ্যিকভাবে উত্পাদিত শিশু...
# 3  বগুড়ার আদমদীঘির সান্তাহারে গতকাল শনিবার ট্রেন...
# 4  যাত্রাবাড়ীর একটি রেস্তোরাঁয় গতকাল বুধবার ভোর...
# 5  পর্যাপ্ত তথ্য-উপাত্ত হাতে নিয়েই কোনো জেলা বা...
# 6  বাংলাদেশ প্রিমিয়ার লিগে গতবার প্রতি ম্যাচে পাঁ...
# 7  লক্ষ্মীপুরের পোদ্দার বাজারে সন্ত্রাসী হামলার শ...
# 8  নিষিদ্ধ পলিথিন ব্যবসায় জড়িত থাকায় এক ব্যবসা...
# 9  নাইকো দুর্নীতি মামলায় হাইকোর্টের দেওয়া রায়ের ব...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80331 entries, 0 to 80330
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   category  80331 non-null  object
#  1   summary   80331 non-null  object
#  2   text      80323 non-null  object
# dtypes: object(3)
# memory usage: 1.8+ MB

# %%
for i in range(5):
    print("Text is \n", data['text'][i], '\n')
    print("Summary is \n", data['summary'][i], '\n\n')
# Out:
# Text is
#  ঢাকা মহানগর ও ঢাকা জেলা আদালত, কিশোরগঞ্জ ও রাঙামাটি জেলার সব আদালতের মামলার সংক্রান্ত তথ্য এখন থেকে মোবাইল অ্যাপসে পাওয়া যাবে।আজ শনিবার ঢাকা মহানগর দায়রা জজ আদালতের জগন্নাথ-সোহেল স্মৃতি মিলনায়তনে এই অ্যাপসের আনুষ্ঠানিক উদ্বোধন করেন প্রধান বিচারপতি সুরেন্দ্র কুমার সিনহা।এই অ্যাপস তৈরির সঙ্গে যুক্ত ইউএনডিপির আইসিটি ম্যানেজার রিয়াজুল আল মাসুম প্রথম আলোকে বলেন, অ্যান্ড্রয়েড মোবাইলের গুগল প্লে স্টোর থেকে ‘বিডি কোর্ট’ নামের অ্যাপসটি ডাউনলোড করা যাবে। তিনি জানান, এই অ্যাপসে আদালতের প্রতিদিনের মামলার কার্যতালিকা, মামলার বিস্তারিত বিবরণ, মামলার ফলাফলসহ অন্যান্য প্রয়োজনীয় তথ্য পাওয়া যাবে। দেশের সব আদালতের মামলা সংক্রান্ত তথ্য এই অ্যাপসের আওতায় আনার কাজ চলছে।মোবাইল অ্যাপসে গিয়ে দেখা গেছে, ‘কজ লিস্ট’ (কার্যতালিকা) ও ‘কেস সার্স’ (মামলা অনুসন্ধান) নামে দুটি বাটন রয়েছে। ‘কজ লিস্ট’ বাটনে ক্লিক করে আদালতের প্রতিদিনকার মামলার তালিকা পাওয়া যাচ্ছে। আর ‘কেস সার্স’ বাটনে ক্লিক করে মামলার পুরো বিবরণ জানা যাচ্ছে।উদ্বোধনী অনুষ্ঠানে ঢাকার জেলা ও দায়রা জজ এস এম কুদ্দুস জামান বলেন, এই অ্যাপসের মাধ্যমে সাধারণ মানুষ মামলার সমস্ত তথ্য জানতে পারবে। এ নিয়ে তাদের যে ভোগান্তি ছিল তা দূর হবে।
#
# Summary is
#  অ্যাপসে মিলবে ঢাকাসহ তিন জেলা আদালতের তথ্য
#
#
# Text is
#  যুক্তরাষ্ট্রে বিজ্ঞান ও প্রকৌশলে পেশা শুরুর
ৃত শিশুর বাড়তি খাদ্য ও উহা ব্যবহারের সরঞ্জামাদি (বিপণন নিয়ন্ত্রণ, ইত্যাদি)’ বিলে এ-সম্পর্কিত একটি বিধান অন্তর্ভুক্ত করার সিদ্ধান্ত নিয়েছে। আজ  মঙ্গলবার জাতীয় সংসদ ভবনে অনুষ্ঠিত কমিটির বৈঠকে এ সিদ্ধান্ত হয়।গত ১৬ জুলাই ‘মাতৃদুগ্ধ বিকল্প শিশুখাদ্য, বাণিজ্যিকভাবে প্রস্তুতকৃত শিশুর বাড়তি খাদ্য ও উহা ব্যবহারের সরঞ্জামাদি (বিপণন নিয়ন্ত্রণ, ইত্যাদি) বিল-২০১৩’ সংসদে উত্থাপিত হয়। পরে এটি পরীক্ষা করে প্রতিবেদন দেওয়ার জন্য সংসদীয় কমিটিতে পাঠানো হয়।বৈঠক শেষে কমিটির সভাপতি শেখ ফজলুল করিম সেলিম সাংবাদিকদের বলেন, বিকল্প শিশুখাদ্য গ্রহণের পর কোনো শিশুর ক্ষতি হলে খাদ্য সরবরাহকারী প্রতিষ্ঠানের বিরুদ্ধে ব্যবস্থা নেওয়ার বিধান বিলে নেই। তাই সংসদীয় কমিটি বিলে দণ্ডবিধি অনুযায়ী জরিমানা ও ক্ষতিপূরণ আদায়সহ অন্যান্য শাস্তির বিধান রাখতে বলেছে।প্রস্তাবিত আইনে বলা হয়েছে, বিকল্প শিশুখাদ্য, শিশুর বাড়তি খাদ্য মায়ের দুধের বিকল্প—এমন ধারণা দিয়ে কোনো ধরনের প্রচারণা চালানো যাবে না। এ ছাড়া বিকল্প শিশুখাদ্যের ওপর যেকোনো ধরনের বিজ্ঞাপন এবং শিশুখাদ্যের মোড়কে শিশু বা মায়ের ছবির ব্যবহার নিষিদ্ধ করা হয়েছে।কমিটির সভাপতি শেখ ফজলুল করিমের সভাপতিত্বে অনুষ্ঠিত বৈঠকে কমিটির সদস্য স্বাস্থ্যমন্ত্রী আ ফ ম রুহুল হক, স্বাস্থ্য প্রতিমন্ত্রী মজিবুর রহমান এবং মোহাম্মদ আমানউল্লাহ, জেড আই এম মোস্তফা আলী ও আমানুর রহমান খান অংশ নেন।
#
# Summary is
#  বিকল্প শিশুখাদ্য গ্রহণে শিশুর মৃত্যু হলে শাস্তির সুপারিশ
#
#
# Text is
#  বগুড়ার আদমদীঘির সান্তাহারে গতকাল শনিবার ট্রেনের নিচে কাটা পড়ে নওগাঁর সাবেক সিভিল সার্জন এ টি এম শাহজাহান আলীর (৬৫) মৃত্যু হয়েছে। তাঁর বাড়ি বগুড়ার শিবগঞ্জ উপজেলার বিহার নিশ্চিন্তপুর গ্রামে।প্রত্যক্ষদর্শী ও সান্তাহার রেলওয়ে জিআরপি থানা থেকে জানা গেছে, সকাল সাড়ে নয়টার দিকে খুলনাগামী তেলবাহী একটি ট্রেন সান্তাহার রেলস্টেশনে দাঁড়িয়ে ছিল। এ সময় ওই ট্রেনের দুই বগির মাঝখান দিয়ে পার হচ্ছিলেন শাহজাহান আলী। কিন্তু ট্রেনটি ছেড়ে দিলে ঘটনাস্থলেই তিনি মারা যান।শাহজাহানের পরিবারের সদস্যরা জানান, তিনি ওই দিন ঢাকা যাওয়ার জন্য নওগাঁর বাঙ্গাবাড়িয়ার বাসা থেকে বের হন।
#
# Summary is
#  ট্রেনে কাটা পড়ে সাবেক সিভিল সার্জনের মৃত্যু
#
#
# Text is
#  যাত্রাবাড়ীর একটি রেস্তোরাঁয় গতকাল বুধবার ভোরে কেরোসিনের চুলা জ্বালানোর সময় দুই কর্মচারী অগ্নিদগ্ধ হয়েছেন। তাঁরা হলেন আমির হোসেন ও হাসান। তাঁদের ঢাকা মেডিকেল কলেজ হাসপাতালের বার্ন ইউনিটে চিকিৎসা দেওয়া হয়েছে।বার্ন ইউনিটে আহত ব্যক্তিরা বলেন, তাঁরা (আমির ও হাসান) যাত্রাবাড়ী মোড় এলাকায় ‘মায়ের দোয়া’ নামের একটি রেস্তোরাঁয় কাজ করেন। গতকাল ভোরে তাঁরা কেরোসিনের চুলা জ্বালানোর সময় হঠাৎ শরীরে আগুন ধরে যায়। এ সময় আগুন নিভিয়ে সহকর্মীরা তাঁদের উদ্ধার করে হাসপাতালে পাঠান।বার্ন ইউনিটের চিকিৎসকেরা বলেন, দগ্ধ ব্যক্তিরা আশঙ্কামুক্ত।
#
# Summary is
#  যাত্রাবাড়ীতে চুলা জ্বালাতে গিয়ে দুই কর্মচারী দগ্ধ

# %%
#data = data.iloc[:5000, :]
#data.head()

# %%
#data.shape

# %% [markdown]
# # Data Cleaning

# %%
def clean_text_summary(columns):
    for row in columns:
        row = str(row) 
        row = row.replace('\n', " ")
        row = row.replace('\t', " ")
        row = row.replace('\\', "")
        row = re.sub('[!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~]', '', row)
        row = re.sub(' +', ' ', row)
        row = row.replace("।", " ")
        row = re.sub('[১২৩৪৫৬৭৮৯০]', '', row)
        row = re.sub('[1234567890]', '', row) 
        row = row.replace('’', '')
        row = row.replace('‘', '')
        
        
        
        row=re.sub("(\\t)", ' ', row) #remove escape charecters
        row=re.sub("(\\r)", ' ', row)
        row=re.sub("(\\n)", ' ', row)
        
        row=re.sub("(__+)", ' ', row)  #remove _ if it occors more than one time consecutively
        row=re.sub("(--+)", ' ', row)   #remove - if it occors more than one time consecutively
        row=re.sub("(~~+)", ' ', row) #remove ~ if it occors more than one time consecutively
        row=re.sub("(\+\++)", ' ', row)   #remove + if it occors more than one time consecutively
        row=re.sub("(\.\.+)", ' ', row)   #remove . if it occors more than one time consecutively
        
        row=re.sub(r"[<>()|&©ø\[\]\'\",;?~*!]", ' ', row) #remove <>()|&©ø"',;?~*!
        
        row=re.sub("(mailto:)", ' ', row) #remove mailto:
        row=re.sub(r"(\\x9\d)", ' ', row) #remove \x9* in text
        row=re.sub("([iI][nN][cC]\d+)", 'INC_NUM', row) #replace INC nums to INC_NUM
        row=re.sub("([cC][mM]\d+)|([cC][hH][gG]\d+)", 'CM_NUM', row)#replace CM# and CHG# to CM_NUM
        
        row=re.sub("(\.\s+)", ' ', row) #remove full stop at end of words(not between)
        row=re.sub("(\-\s+)", ' ', row) #remove - at end of words(not between)
        row=re.sub("(\:\s+)", ' ', row) #remove : at end of words(not between)
        
        row=re.sub("(\s+.\s+)", ' ', row) #remove any single charecters hanging between 2 spaces
        
        #Replace any url as such https://abc.xyz.net/browse/sdf-5327 ====> abc.xyz.net
        try:
            url = re.search(r'((https*:\/*)([^\/\s]+))(.[^\s]+)', row)
            repl_url = url.group(3)
            row = re.sub(r'((https*:\/*)([^\/\s]+))(.[^\s]+)',repl_url, row)
        except:
            pass #there might be emails with no url in them
        
        row = re.sub("(\s+)",' ', row) #remove multiple spaces
        
        #Should always be last
        row=re.sub("(\s+.\s+)", ' ', row) #remove any single charecters hanging between 2 spaces

        yield row

# %%
text_cleaning = clean_text_summary(data['text'])
summary_cleaning = clean_text_summary(data['summary'])

# %%
import spacy

nlp = spacy.load("en_core_web_sm")

text_cleaning = clean_text_summary(data['text'])
summary_cleaning = clean_text_summary(data['summary'])

text = [str(doc) for doc in nlp.pipe(text_cleaning, batch_size=5000)]
summary = [str(doc) for doc in nlp.pipe(summary_cleaning, batch_size=5000)]

for i in range(5):
    print("Text is :\n", text[i], '\n')
    print("Summary is :\n", summary[i], '\n\n')
# Out:
# Text is :
#  ঢাকা মহানগর ঢাকা জেলা আদালত কিশোরগঞ্জ রাঙামাটি জেলার সব আদালতের মামলার সংক্রান্ত তথ্য এখন থেকে মোবাইল অ্যাপসে পাওয়া যাবে আজ শনিবার ঢাকা মহানগর দায়রা জজ আদালতের জগন্নাথসোহেল স্মৃতি মিলনায়তনে এই অ্যাপসের আনুষ্ঠানিক উদ্বোধন করেন প্রধান বিচারপতি সুরেন্দ্র কুমার সিনহা এই অ্যাপস তৈরির সঙ্গে যুক্ত ইউএনডিপির আইসিটি ম্যানেজার রিয়াজুল আল মাসুম প্রথম আলোকে বলেন অ্যান্ড্রয়েড মোবাইলের গুগল প্লে স্টোর থেকে বিডি কোর্ট নামের অ্যাপসটি ডাউনলোড করা যাবে তিনি জানান এই অ্যাপসে আদালতের প্রতিদিনের মামলার কার্যতালিকা মামলার বিস্তারিত বিবরণ মামলার ফলাফলসহ অন্যান্য প্রয়োজনীয় তথ্য পাওয়া যাবে দেশের সব আদালতের মামলা সংক্রান্ত তথ্য এই অ্যাপসের আওতায় আনার কাজ চলছে মোবাইল অ্যাপসে গিয়ে দেখা গেছে কজ লিস্ট কার্যতালিকা কেস সার্স মামলা অনুসন্ধান নামে দুটি বাটন রয়েছে কজ লিস্ট বাটনে ক্লিক করে আদালতের প্রতিদিনকার মামলার তালিকা পাওয়া যাচ্ছে আর কেস সার্স বাটনে ক্লিক করে মামলার পুরো বিবরণ জানা যাচ্ছে উদ্বোধনী অনুষ্ঠানে ঢাকার জেলা দায়রা জজ এস এম কুদ্দুস জামান বলেন এই অ্যাপসের মাধ্যমে সাধারণ মানুষ মামলার সমস্ত তথ্য জানতে পারবে নিয়ে তাদের যে ভোগান্তি ছিল তা দূর হবে
#
# Summary is :
#  অ্যাপসে মিলবে ঢাকাসহ তিন জেলা আদালতের তথ্য
#
#
# Text is :
ট্রেনে কাটা পড়ে সাবেক সিভিল সার্জনের মৃত্যু
#
#
# Text is :
#  যাত্রাবাড়ীর একটি রেস্তোরাঁয় গতকাল বুধবার ভোরে কেরোসিনের চুলা জ্বালানোর সময় দুই কর্মচারী অগ্নিদগ্ধ হয়েছেন তাঁরা হলেন আমির হোসেন হাসান তাঁদের ঢাকা মেডিকেল কলেজ হাসপাতালের বার্ন ইউনিটে চিকিৎসা দেওয়া হয়েছে বার্ন ইউনিটে আহত ব্যক্তিরা বলেন তাঁরা আমির হাসান যাত্রাবাড়ী মোড় এলাকায় মায়ের দোয়া নামের একটি রেস্তোরাঁয় কাজ করেন গতকাল ভোরে তাঁরা কেরোসিনের চুলা জ্বালানোর সময় হঠাৎ শরীরে আগুন ধরে যায় সময় আগুন নিভিয়ে সহকর্মীরা তাঁদের উদ্ধার করে হাসপাতালে পাঠান বার্ন ইউনিটের চিকিৎসকেরা বলেন দগ্ধ ব্যক্তিরা আশঙ্কামুক্ত
#
# Summary is :
#  যাত্রাবাড়ীতে চুলা জ্বালাতে গিয়ে দুই কর্মচারী দগ্ধ

# %%
t = time()

#Batch the data points into 5000 and run on all cores for faster preprocessing
summary = ['_START_ '+ str(doc) + ' _END_' for doc in nlp.pipe(summary_cleaning, batch_size=5000, n_threads=-1)]

#Takes 7-8 mins
print('Time to clean up everything: {} mins'.format(round((time() - t) / 60, 2)))
# Out:
# Time to clean up everything: 0.74 mins

# %%
for i in range(5):
    print("Text is :\n", text[i], '\n')
    print("Summary is :\n", summary[i], '\n\n')
# Out:
# Text is :
#  ঢাকা মহানগর ঢাকা জেলা আদালত কিশোরগঞ্জ রাঙামাটি জেলার সব আদালতের মামলার সংক্রান্ত তথ্য এখন থেকে মোবাইল অ্যাপসে পাওয়া যাবে আজ শনিবার ঢাকা মহানগর দায়রা জজ আদালতের জগন্নাথসোহেল স্মৃতি মিলনায়তনে এই অ্যাপসের আনুষ্ঠানিক উদ্বোধন করেন প্রধান বিচারপতি সুরেন্দ্র কুমার সিনহা এই অ্যাপস তৈরির সঙ্গে যুক্ত ইউএনডিপির আইসিটি ম্যানেজার রিয়াজুল আল মাসুম প্রথম আলোকে বলেন অ্যান্ড্রয়েড মোবাইলের গুগল প্লে স্টোর থেকে বিডি কোর্ট নামের অ্যাপসটি ডাউনলোড করা যাবে তিনি জানান এই অ্যাপসে আদালতের প্রতিদিনের মামলার কার্যতালিকা মামলার বিস্তারিত বিবরণ মামলার ফলাফলসহ অন্যান্য প্রয়োজনীয় তথ্য পাওয়া যাবে দেশের সব আদালতের মামলা সংক্রান্ত তথ্য এই অ্যাপসের আওতায় আনার কাজ চলছে মোবাইল অ্যাপসে গিয়ে দেখা গেছে কজ লিস্ট কার্যতালিকা কেস সার্স মামলা অনুসন্ধান নামে দুটি বাটন রয়েছে কজ লিস্ট বাটনে ক্লিক করে আদালতের প্রতিদিনকার মামলার তালিকা পাওয়া যাচ্ছে আর কেস সার্স বাটনে ক্লিক করে মামলার পুরো বিবরণ জানা যাচ্ছে উদ্বোধনী অনুষ্ঠানে ঢাকার জেলা দায়রা জজ এস এম কুদ্দুস জামান বলেন এই অ্যাপসের মাধ্যমে সাধারণ মানুষ মামলার সমস্ত তথ্য জানতে পারবে নিয়ে তাদের যে ভোগান্তি ছিল তা দূর হবে
#
# Summary is :
#  অ্যাপসে মিলবে ঢাকাসহ তিন জেলা আদালতের তথ্য
#
#
# Text is :
#  যুক্তরাষ্ট্রে বিজ্ঞান প্রকৌশলে পেশা শুরুর প্রাথমিক পর্যায়ের গবেষকদের সর্বোচ্চ সম্মাননা হলো প্রেসিডেনশিয়াল আরলি ক্যারিয়ার অ্যাওয়ার্ড ফর সায়েন্টিস্টস অ্যান্ড ইঞ্জিনিয়ার্স এবার সেই সম্মাননায় ভূষিত হলেন বাংলাদেশি গবেষক সাইফ সালাহউদ্দিন এই বসন্তে ওয়া​শিংটন ডিসিতে বিশেষ অনুষ্ঠানে সাইফ সালাহউদ্দিনসহ জনকে আনুষ্ঠানিকভাবে সম্মাননা জানানো হবে মার্কিন প্রেসিডেন্টের দপ্তর হোয়াইট হাউস থেকে দেওয়া বিজ্ঞপ্তিতে জানানো হয় এবার প্রেসিডেনশিয়াল আরলি ক্যারিয়ার অ্যাওয়ার্ড ফর সায়েন্টিস্টস অ্যান্ড ইঞ্জিনিয়ার্স সম্মাননার জন্য প্রেসিডেন্ট বারাক ওবামা জনের নাম ঘোষণা করেছেন সেই তালিকায় আছেন বাংলাদেশি সাইফ সালাহউদ্দিন বাংলাদেশ প্রকৌশল বিশ্ববিদ্যালয়ের সাবেক শিক্ষার্থী সাইফ সালাহউদ্দিন বর্তমানে যুক্তরাষ্ট্রের ক্যালিফোর্নিয়া বিশ্ববিদ্যালয় বার্কলেতে শিক্ষকতা করছেন প্রেসিডেন্ট ওবামা বলেন পেশাগত জীবন শুরুর পর্যায়ের এই বিজ্ঞানীদের প্রচেষ্টা জলবায়ু পরিবর্তনের কারণে আমাদের স্বাস্থ্য সুস্থতার প্রতি​ চ্যালেঞ্জগুলোর মুখোমুখি হওয়া বা সেগুলো বোঝার ক্ষেত্রে পথ দেখাবে আমরা এই বিজ্ঞ ব্যক্তিদের অভিনন্দন জানাই একই সঙ্গে বিস্ময়কর দৃষ্টান্ত স্থাপন করার জন্য সামনের দিকে এগিয়ে যাওয়ার আহ্বান জানাই প্রেসিডেনশিয়াল আরলি ক্যারিয়ার অ্যাওয়ার্ড ফর সায়েন্টিস্টস অ্যান্ড ইঞ্জিনিয়ার্স সম্মাননা তাদেরই দেওয়া হয় যাঁরা যুক্তরাষ্ট্রে বিভিন্ন জায়গায় পেশা শুরুর প্রাথমিক পর্যায়েই মার্কিন অর্থনীতিকে এগিয়ে নেওয়ার ক্ষেত্রে বা বড় বড় চ্যালেঞ্জগুলো মোকাবিলায় বিশেষ অবদান রাখতে সক্ষম হন সালের মার্কিন প্রেসিডেন্ট বিল ক্লিনটন এই অ্যাওয়ার্ড চালু করেন
#
# Summary is :
#  বিজ্ঞান প্রকৌশলে মার্কিন সর্বোচ্চ সম্মাননা পাচ্ছেন বাংলাদেশি গবেষক
#
#
# Text is :
গুড়ার আদমদীঘির সান্তাহারে গতকাল শনিবার ট্রেনের নিচে কাটা পড়ে নওগাঁর সাবেক সিভিল সার্জন টি এম শাহজাহান আলীর মৃত্যু হয়েছে তাঁর বাড়ি বগুড়ার শিবগঞ্জ উপজেলার বিহার নিশ্চিন্তপুর গ্রামে প্রত্যক্ষদর্শী সান্তাহার রেলওয়ে জিআরপি থানা থেকে জানা গেছে সকাল সাড়ে নয়টার দিকে খুলনাগামী তেলবাহী একটি ট্রেন সান্তাহার রেলস্টেশনে দাঁড়িয়ে ছিল সময় ওই ট্রেনের দুই বগির মাঝখান দিয়ে পার হচ্ছিলেন শাহজাহান আলী কিন্তু ট্রেনটি ছেড়ে দিলে ঘটনাস্থলেই তিনি মারা যান শাহজাহানের পরিবারের সদস্যরা জানান তিনি ওই দিন ঢাকা যাওয়ার জন্য নওগাঁর বাঙ্গাবাড়িয়ার বাসা থেকে বের হন
#
# Summary is :
#  ট্রেনে কাটা পড়ে সাবেক সিভিল সার্জনের মৃত্যু
#
#
# Text is :
#  যাত্রাবাড়ীর একটি রেস্তোরাঁয় গতকাল বুধবার ভোরে কেরোসিনের চুলা জ্বালানোর সময় দুই কর্মচারী অগ্নিদগ্ধ হয়েছেন তাঁরা হলেন আমির হোসেন হাসান তাঁদের ঢাকা মেডিকেল কলেজ হাসপাতালের বার্ন ইউনিটে চিকিৎসা দেওয়া হয়েছে বার্ন ইউনিটে আহত ব্যক্তিরা বলেন তাঁরা আমির হাসান যাত্রাবাড়ী মোড় এলাকায় মায়ের দোয়া নামের একটি রেস্তোরাঁয় কাজ করেন গতকাল ভোরে তাঁরা কেরোসিনের চুলা জ্বালানোর সময় হঠাৎ শরীরে আগুন ধরে যায় সময় আগুন নিভিয়ে সহকর্মীরা তাঁদের উদ্ধার করে হাসপাতালে পাঠান বার্ন ইউনিটের চিকিৎসকেরা বলেন দগ্ধ ব্যক্তিরা আশঙ্কামুক্ত
#
# Summary is :
#  যাত্রাবাড়ীতে চুলা জ্বালাতে গিয়ে দুই কর্মচারী দগ্ধ

# %%
pre = pd.DataFrame()
pre['cleaned_text'] = pd.Series(text)
pre['cleaned_summary'] = pd.Series(summary)
pre.head()
# Out:
#                                         cleaned_text  \
# 0  ঢাকা মহানগর ঢাকা জেলা আদালত কিশোরগঞ্জ রাঙামাটি...
# 1  যুক্তরাষ্ট্রে বিজ্ঞান প্রকৌশলে পেশা শুরুর প্র...
# 2  বিকল্প শিশুখাদ্য বাণিজ্যিকভাবে উত্পাদিত শিশুখা...
# 3  বগুড়ার আদমদীঘির সান্তাহারে গতকাল শনিবার ট্রেন...
# 4  যাত্রাবাড়ীর একটি রেস্তোরাঁয় গতকাল বুধবার ভোর...
#
#                                      cleaned_summary
# 0         অ্যাপসে মিলবে ঢাকাসহ তিন জেলা আদালতের তথ্য
# 1  বিজ্ঞান প্রকৌশলে মার্কিন সর্বোচ্চ সম্মাননা প...
# 2  বিকল্প শিশুখাদ্য গ্রহণে শিশুর মৃত্যু হলে শাস্ত...
# 3       ট্রেনে কাটা পড়ে সাবেক সিভিল সার্জনের মৃত্যু
# 4  যাত্রাবাড়ীতে চুলা জ্বালাতে গিয়ে দুই কর্মচারী ...

# %%
pre.shape
# Out:
# (80331, 2)

# %% [markdown]
# # Counting Words

# %%
text_count = []
summary_count = []

# %%
for sent in pre['cleaned_text']:
    text_count.append(len(sent.split()))
for sent in pre['cleaned_summary']:
    summary_count.append(len(sent.split()))

# %%
graph_df= pd.DataFrame()
graph_df['text']=text_count
graph_df['summary']=summary_count
graph_df.head()
# Out:
#    text  summary
# 0   163        7
# 1   178        8
# 2   209        8
# 3    82        7
# 4    75        7

# %%
graph_df.hist(bins = 5)
plt.show()

# %% [markdown]
# # Percent of the word

# %%
#Check how much % of summary have 0-15 words
cnt=0
for i in pre['cleaned_summary']:
    if(len(i.split())<=15):
        cnt=cnt+1
print(cnt/len(pre['cleaned_summary']))
# Out:
# 0.9999128605395178

# %%
#Check how much % of text have 0-70 words
cnt=0
for i in pre['cleaned_text']:
    if(len(i.split())<=100):
        cnt=cnt+1
print(cnt/len(pre['cleaned_text']))
# Out:
# 0.07038378708095255

# %% [markdown]
# # Selecting text and summary

# %%
#Model to summarize the text between 0-15 words for Summary and 0-100 words for Text
max_text_len=100
max_summary_len=15

# %%
cleaned_text =np.array(pre['cleaned_text'])
cleaned_summary=np.array(pre['cleaned_summary'])

short_text=[]
short_summary=[]

for i in range(len(cleaned_text)):
    if(len(cleaned_summary[i].split())<=max_summary_len and len(cleaned_text[i].split())<=max_text_len):
        short_text.append(cleaned_text[i])
        short_summary.append(cleaned_summary[i])
        
post_pre=pd.DataFrame({'text':short_text,'summary':short_summary})
post_pre.head()
# Out:
#                                                 text  \
# 0  বগুড়ার আদমদীঘির সান্তাহারে গতকাল শনিবার ট্রেন...
# 1  যাত্রাবাড়ীর একটি রেস্তোরাঁয় গতকাল বুধবার ভোর...
# 2   ওভারের ম্যাচ তাতেই চার আর ছয়ে রান করেছেন লাল...
# 3  ঢাকা মহানগর আওয়ামী লীগের ভারপ্রাপ্ত সভাপতি এম ...
# 4  সম্প্রতি চালু হওয়া বিমান বাংলাদেশ এয়ারলাইন্স...
#
#                                              summary
# 0       ট্রেনে কাটা পড়ে সাবেক সিভিল সার্জনের মৃত্যু
# 1  যাত্রাবাড়ীতে চুলা জ্বালাতে গিয়ে দুই কর্মচারী ...
# 2   ওভারের ম্যাচে ট্রিপল সেঞ্চুরি লালমনিরহাটের স্...
# 3                  এম আজিজের জন্য আলীগের দোয়া মাহফিল
# 4  বিমানের টিকিট কাটতে দেশিবিদেশি কার্ড নেওয়া হচ্ছে

# %%
# Shape of post_pre 
post_pre.shape
# Out:
# (5654, 2)

# %%
#Add sostok and eostok at 
post_pre['summary'] = post_pre['summary'].apply(lambda x : 'sostok '+ x + ' eostok')
#post_pre.head()

for i in range(3):
    print(post_pre['text'][i], '\n')
    print(post_pre['summary'][i], '\n\n')
# Out:
# বগুড়ার আদমদীঘির সান্তাহারে গতকাল শনিবার ট্রেনের নিচে কাটা পড়ে নওগাঁর সাবেক সিভিল সার্জন টি এম শাহজাহান আলীর মৃত্যু হয়েছে তাঁর বাড়ি বগুড়ার শিবগঞ্জ উপজেলার বিহার নিশ্চিন্তপুর গ্রামে প্রত্যক্ষদর্শী সান্তাহার রেলওয়ে জিআরপি থানা থেকে জানা গেছে সকাল সাড়ে নয়টার দিকে খুলনাগামী তেলবাহী একটি ট্রেন সান্তাহার রেলস্টেশনে দাঁড়িয়ে ছিল সময় ওই ট্রেনের দুই বগির মাঝখান দিয়ে পার হচ্ছিলেন শাহজাহান আলী কিন্তু ট্রেনটি ছেড়ে দিলে ঘটনাস্থলেই তিনি মারা যান শাহজাহানের পরিবারের সদস্যরা জানান তিনি ওই দিন ঢাকা যাওয়ার জন্য নওগাঁর বাঙ্গাবাড়িয়ার বাসা থেকে বের হন
#
# sostok ট্রেনে কাটা পড়ে সাবেক সিভিল সার্জনের মৃত্যু eostok
#
#
# যাত্রাবাড়ীর একটি রেস্তোরাঁয় গতকাল বুধবার ভোরে কেরোসিনের চুলা জ্বালানোর সময় দুই কর্মচারী অগ্নিদগ্ধ হয়েছেন তাঁরা হলেন আমির হোসেন হাসান তাঁদের ঢাকা মেডিকেল কলেজ হাসপাতালের বার্ন ইউনিটে চিকিৎসা দেওয়া হয়েছে বার্ন ইউনিটে আহত ব্যক্তিরা বলেন তাঁরা আমির হাসান যাত্রাবাড়ী মোড় এলাকায় মায়ের দোয়া নামের একটি রেস্তোরাঁয় কাজ করেন গতকাল ভোরে তাঁরা কেরোসিনের চুলা জ্বালানোর সময় হঠাৎ শরীরে আগুন ধরে যায় সময় আগুন নিভিয়ে সহকর্মীরা তাঁদের উদ্ধার করে হাসপাতালে পাঠান বার্ন ইউনিটের চিকিৎসকেরা বলেন দগ্ধ ব্যক্তিরা আশঙ্কামুক্ত
#
# sostok যাত্রাবাড়ীতে চুলা জ্বালাতে গিয়ে দুই কর্মচারী দগ্ধ eostok
#
#
#  ওভারের ম্যাচ তাতেই চার আর ছয়ে রান করেছেন লালমানিরহাট সরকারি উচ্চবিদ্যালয়ের শিক্ষার্থী লিপু জাতীয় স্কুল তো বটেই বয়সভিত্তিক পর্যায়েই এটি সর্বোচ্চ রান আজ শুক্রবার ইয়ং টাইগার্স জাতীয় স্কুল ক্রিকেট প্রতিযোগিতায় লালমনিরহাট সরকারি উচ্চবিদ্যালয়ের পক্ষে রেকর্ড গড়েছেন মোস্তাফিজুর রহমান লিপু লালমনিরহাটের শেখ কামাল স্টেডিয়ামে ম্যাচটি অনুষ্ঠিত হয় লালমনিরহাট ক্রিকেট একাডেমির খেলোয়াড় লিপু বাংলাদেশ অনূর্ধ্ব দলেরও একজন সদস্য ম্যাচে লিপুর রানের ওপর ভর করে উইকেটে রান করে লালমনিরহাট সরকারি উচ্চবিদ্যালয় জবাবে স্থানীয় গিয়াস উদ্দিন উচ্চবিদ্যালয় রানে অলআউট হলে রানে পরাজিত হয় বাংলাদেশ ক্রিকেট বোর্ডের কর্মকর্তা বুলবুল বাশার জানান বয়সভিত্তিক এবং জাতীয় স্কুল ক্রিকেটের সীমিত ওভারের যেকোনো প্রতিযোগিতায় এটিই ব্যক্তিগত দলীয় সর্বোচ্চ ইনিংস
#
# sostok  ওভারের ম্যাচে ট্রিপল সেঞ্চুরি লালমনিরহাটের স্কুলছাত্রের eostok

# %% [markdown]
# # Splitting dataset

# %%
x_tr,x_val,y_tr,y_val = train_test_split(np.array(post_pre['text']), np.array(post_pre['summary']), test_size=0.1, random_state=0, shuffle=True)

# %% [markdown]
# # Finding word frequency for x_train and x_valid

# %%
#prepare a tokenizer for reviews on training data
x_tokenizer = Tokenizer() 
x_tokenizer.fit_on_texts(list(x_tr))

# %%
thresh=4

cnt=0
tot_cnt=0
freq=0
tot_freq=0

for key,value in x_tokenizer.word_counts.items():
    tot_cnt=tot_cnt+1
    tot_freq=tot_freq+value
    if(value<thresh):
        cnt=cnt+1
        freq=freq+value
    
print("% of rare words in vocabulary:",(cnt/tot_cnt)*100)
print("Total Coverage of rare words:",(freq/tot_freq)*100)
# Out:
# % of rare words in vocabulary: 72.29214491147525
# Total Coverage of rare words: 9.799637088075933

# %%
len(x_tokenizer.index_word)
# Out:
# 37899

# %% [markdown]
# # Tokenizer and pad sequence for x_train and x_valid

# %%
#prepare a tokenizer for reviews on training data
x_tokenizer = Tokenizer(num_words=tot_cnt-cnt) 
x_tokenizer.fit_on_texts(list(x_tr))

#convert text sequences into integer sequences (i.e one-hot encodeing all the words)
x_tr_seq    =   x_tokenizer.texts_to_sequences(x_tr) 
x_val_seq   =   x_tokenizer.texts_to_sequences(x_val)

#padding zero upto maximum length
x_tr    =   pad_sequences(x_tr_seq,  maxlen=max_text_len, padding='post')
x_val   =   pad_sequences(x_val_seq, maxlen=max_text_len, padding='post')

#size of vocabulary ( +1 for padding token)
x_voc   =  x_tokenizer.num_words + 1

print("Size of vocabulary in X = {}".format(x_voc))
# Out:
# Size of vocabulary in X = 10502

# %% [markdown]
# # Finding word frequency for y_train and y_valid

# %%
#prepare a tokenizer for reviews on training data
y_tokenizer = Tokenizer()   
y_tokenizer.fit_on_texts(list(y_tr))

# %%
thresh=6

cnt=0
tot_cnt=0
freq=0
tot_freq=0

for key,value in y_tokenizer.word_counts.items():
    tot_cnt=tot_cnt+1
    tot_freq=tot_freq+value
    if(value<thresh):
        cnt=cnt+1
        freq=freq+value
    
print("% of rare words in vocabulary:",(cnt/tot_cnt)*100)
print("Total Coverage of rare words:",(freq/tot_freq)*100)
# Out:
# % of rare words in vocabulary: 87.63041733547352
# Total Coverage of rare words: 30.684625981238927

# %% [markdown]
# # Tokenizer and pad sequence for y_train and y_valid

# %%
#prepare a tokenizer for reviews on training data
y_tokenizer = Tokenizer(num_words=tot_cnt-cnt) 
y_tokenizer.fit_on_texts(list(y_tr))

#convert text sequences into integer sequences (i.e one hot encode the text in Y)
y_tr_seq    =   y_tokenizer.texts_to_sequences(y_tr) 
y_val_seq   =   y_tokenizer.texts_to_sequences(y_val) 

#padding zero upto maximum length
y_tr    =   pad_sequences(y_tr_seq, maxlen=max_summary_len, padding='post')
y_val   =   pad_sequences(y_val_seq, maxlen=max_summary_len, padding='post')

#size of vocabulary
y_voc  =   y_tokenizer.num_words +1
print("Size of vocabulary in Y = {}".format(y_voc))
# Out:
# Size of vocabulary in Y = 1234

# %% [markdown]
# # Checking Empty word and removing

# %%
ind=[]
for i in range(len(y_tr)):
    cnt=0
    for j in y_tr[i]:
        if j!=0:
            cnt=cnt+1
    if(cnt==2):
        ind.append(i)

y_tr=np.delete(y_tr,ind, axis=0)
x_tr=np.delete(x_tr,ind, axis=0)

# %%
ind=[]
for i in range(len(y_val)):
    cnt=0
    for j in y_val[i]:
        if j!=0:
            cnt=cnt+1
    if(cnt==2):
        ind.append(i)

y_val=np.delete(y_val,ind, axis=0)
x_val=np.delete(x_val,ind, axis=0)

# %%
x_tr.shape
# Out:
# (5065, 100)

# %%
y_tr.shape
# Out:
# (5065, 15)

# %%
x_val.shape
# Out:
# (561, 100)

# %%
y_val.shape
# Out:
# (561, 15)

# %% [markdown]
# # Model

# %%
latent_dim = 300
embedding_dim = 200

# %%
# Encoder
encoder_inputs = Input(shape=(max_text_len,))

#embedding layer
enc_emb =  Embedding(x_voc, embedding_dim,trainable=True)(encoder_inputs)

#encoder lstm 1
encoder_lstm1 = LSTM(latent_dim,return_sequences=True,return_state=True,dropout=0.4,recurrent_dropout=0.4)
encoder_output1, state_h1, state_c1 = encoder_lstm1(enc_emb)

#encoder lstm 2
encoder_lstm2 = LSTM(latent_dim,return_sequences=True,return_state=True,dropout=0.4,recurrent_dropout=0.4)
encoder_output2, state_h2, state_c2 = encoder_lstm2(encoder_output1)

#encoder lstm 3
encoder_lstm3=LSTM(latent_dim, return_state=True, return_sequences=True,dropout=0.4,recurrent_dropout=0.4)
encoder_outputs, state_h, state_c= encoder_lstm3(encoder_output2)



# Set up the decoder, using `encoder_states` as initial state.
decoder_inputs = Input(shape=(None,))

#embedding layer
dec_emb_layer = Embedding(y_voc, embedding_dim,trainable=True)
dec_emb = dec_emb_layer(decoder_inputs)

decoder_lstm = LSTM(latent_dim, return_sequences=True, return_state=True,dropout=0.4,recurrent_dropout=0.2)
decoder_outputs,decoder_fwd_state, decoder_back_state = decoder_lstm(dec_emb,initial_state=[state_h, state_c])

#dense layer
decoder_dense =  TimeDistributed(Dense(y_voc, activation='softmax'))
decoder_outputs = decoder_dense(decoder_outputs)

# Define the model 
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 100)]        0           []
#
#  embedding (Embedding)          (None, 100, 200)     2100400     ['input_1[0][0]']
#
#  lstm (LSTM)                    [(None, 100, 300),   601200      ['embedding[0][0]']
#                                  (None, 300),
#                                  (None, 300)]
#
#  input_2 (InputLayer)           [(None, None)]       0           []
#
#  lstm_1 (LSTM)                  [(None, 100, 300),   721200      ['lstm[0][0]']
#                                  (None, 300),
#                                  (None, 300)]
#
#  embedding_1 (Embedding)        (None, None, 200)    246800      ['input_2[0][0]']
#
#  lstm_2 (LSTM)                  [(None, 100, 300),   721200      ['lstm_1[0][0]']
#                                  (None, 300),
#                                  (None, 300)]
#
#  lstm_3 (LSTM)                  [(None, None, 300),  601200      ['embedding_1[0][0]',
#                                  (None, 300),                     'lstm_2[0][1]',
#                                  (None, 300)]                     'lstm_2[0][2]']
#
#  time_distributed (TimeDistribu  (None, None, 1234)  371434      ['lstm_3[0][0]']
#  ted)
#
# ==================================================================================================
# Total params: 5,363,434
# Trainable params: 5,363,434
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model.compile(optimizer='rmsprop', 
              loss='sparse_categorical_crossentropy')

# %%
es = EarlyStopping(monitor='val_loss', 
                   mode='min', 
                   verbose=1,
                   patience=50)

# %%
history=model.fit([x_tr, y_tr[:,:-1]], 
                  y_tr.reshape(y_tr.shape[0],y_tr.shape[1], 1)[:,1
200
# 40/40 [==============================] - 121s 3s/step - loss: 1.4086 - val_loss: 1.7727
# Epoch 160/200
# 40/40 [==============================] - 120s 3s/step - loss: 1.4030 - val_loss: 1.7746
# Epoch 161/200
# 40/40 [==============================] - 121s 3s/step - loss: 1.4002 - val_loss: 1.7744
# Epoch 162/200
# 40/40 [==============================] - 121s 3s/step - loss: 1.3948 - val_loss: 1.7775
# Epoch 163/200
# 40/40 [==============================] - 121s 3s/step - loss: 1.3899 - val_loss: 1.7751
# Epoch 164/200
# 40/40 [==============================] - 120s 3s/step - loss: 1.3862 - val_loss: 1.7751
# Epoch 165/200
# 40/40 [==============================] - 121s 3s/step - loss: 1.3809 - val_loss: 1.7755
# Epoch 166/200
# 40/40 [==============================] - 120s 3s/step - loss: 1.3780 - val_loss: 1.7761
# Epoch 167/200
# 40/40 [==============================] - 121s 3s/step - loss: 1.3737 - val_loss: 1.7783
# Epoch 168/200
# 40/40 [==============================] - 120s 3s/step - loss: 1.3684 - val_loss: 1.7768
# Epoch 169/200
# 40/40 [==============================] - 121s 3s/step - loss: 1.3651 - val_loss: 1.7775
# Epoch 170/200
# 40/40 [==============================] - 120s 3s/step - loss: 1.3604 - val_loss: 1.7772
# Epoch 171/200
# 40/40 [==============================] - 120s 3s/step - loss: 1.3554 - val_loss: 1.7817
# Epoch 172/200
# 40/40 [==============================] - 120s 3s/step - loss: 1.3509 - val_loss: 1.7764
# Epoch 173/200
# 40/40 [==============================] - 121s 3s/step - loss: 1.3477 - val_loss: 1.7812
# Epoch 174/200
# 40/40 [==============================] - 120s 3s/step - loss: 1.3421 - val_loss: 1.7798
# Epoch 175/200
# 40/40 [==============================] - 120s 3s/step - loss: 1.3379 - val_loss: 1.7810
# Epoch 176/200
# 40/40 [==============================] - 120s 3s/step - loss: 1.3341 - val_loss: 1.7814
# Epoch 177/200
# 40/40 [==============================] - 121s 3s/step - loss: 1.3290 - val_loss: 1.7838
# Epoch 178/200
# 40/40 [==============================] - 120s 3s/step - loss: 1.3257 - val_loss: 1.7821
# Epoch 179/200
# 40/40 [==============================] - 121s 3s/step - loss: 1.3220 - val_loss: 1.7857
# Epoch 180/200
# 40/40 [==============================] - 121s 3s/step - loss: 1.3169 - val_loss: 1.7852
# Epoch 181/200
# 40/40 [==============================] - 120s 3s/step - loss: 1.3133 - val_loss: 1.7868
# Epoch 182/200
# 40/40 [==============================] - 120s 3s/step - loss: 1.3073 - val_loss: 1.7842
# Epoch 183/200
# 40/40 [==============================] - 121s 3s/step - loss: 1.3052 - val_loss: 1.7843
# Epoch 184/200
# 40/40 [==============================] - 121s 3s/step - loss: 1.3018 - val_loss: 1.7874
# Epoch 185/200
# 40/40 [==============================] - 121s 3s/step - loss: 1.2967 - val_loss: 1.7881
# Epoch 186/200
# 40/40 [==============================] - 121s 3s/step - loss: 1.2926 - val_loss: 1.7882
# Epoch 187/200
# 40/40 [==============================] - 121s 3s/step - loss: 1.2900 - val_loss: 1.7875
# Epoch 188/200
# 40/40 [==============================] - 121s 3s/step - loss: 1.2866 - val_loss: 1.7874
# Epoch 189/200
# 40/40 [==============================] - 121s 3s/step - loss: 1.2809 - val_loss: 1.7894
# Epoch 190/200
# 40/40 [==============================] - 120s 3s/step - loss: 1.2768 - val_loss: 1.7890
# Epoch 191/200
# 40/40 [==============================] - 120s 3s/step - loss: 1.2719 - val_loss: 1.7917
# Epoch 192/200
# 40/40 [==============================] - 120s 3s/step - loss: 1.2691 - val_loss: 1.7907
# Epoch 193/200
# 40/40 [==============================] - 120s 3s/step - loss: 1.2651 - val_loss: 1.7924
# Epoch 194/200
# 40/40 [==============================] - 121s 3s/step - loss: 1.2620 - val_loss: 1.7937
# Epoch 195/200
# 40/40 [==============================] - 120s 3s/step - loss: 1.2564 - val_loss: 1.7939
# Epoch 196/200
# 40/40 [==============================] - 121s 3s/step - loss: 1.2547 - val_loss: 1.7949
# Epoch 197/200
# 40/40 [==============================] - 120s 3s/step - loss: 1.2491 - val_loss: 1.7986
# Epoch 198/200
# 40/40 [==============================] - 121s 3s/step - loss: 1.2462 - val_loss: 1.7950
# Epoch 199/200
# 40/40 [==============================] - 120s 3s/step - loss: 1.2427 - val_loss: 1.7950
# Epoch 199: early stopping

# %%
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()

# %%
reverse_target_word_index=y_tokenizer.index_word
reverse_source_word_index=x_tokenizer.index_word
target_word_index=y_tokenizer.word_index

# %%
# Encode the input sequence to get the feature vector
encoder_model = Model(inputs=encoder_inputs,outputs=[encoder_outputs, state_h, state_c])

# Decoder setup
# Below tensors will hold the states of the previous time step
decoder_state_input_h = Input(shape=(latent_dim,))
decoder_state_input_c = Input(shape=(latent_dim,))
decoder_hidden_state_input = Input(shape=(max_text_len,latent_dim))

# Get the embeddings of the decoder sequence
dec_emb2= dec_emb_layer(decoder_inputs) 
# To predict the next word in the sequence, set the initial states to the states from the previous time step
decoder_outputs2, state_h2, state_c2 = decoder_lstm(dec_emb2, initial_state=[decoder_state_input_h, decoder_state_input_c])

# A dense softmax layer to generate prob dist. over the target vocabulary
decoder_outputs2 = decoder_dense(decoder_outputs2) 

# Final decoder model
decoder_model = Model(
    [decoder_inputs] + [decoder_hidden_state_input,decoder_state_input_h, decoder_state_input_c],
    [decoder_outputs2] + [state_h2, state_c2])

# %%
target_word_index
# Out:
# {'sostok': 1,
#  'eostok': 2,
#  'থেকে': 3,
#  'দুই': 4,
#  'শুরু': 5,
#  'না': 6,
#  'সঙ্গে': 7,
#  'নিহত': 8,
#  'গ্রেপ্তার': 9,
#  'চুক্তি': 10,
#  'হবে': 11,
#  'আটক': 12,
#  'নতুন': 13,
#  'ব্যাংক': 14,
#  'ব্যাংকের': 15,
#  'উদ্ধার': 16,
#  'মধ্যে': 17,
#  'নিয়ে': 18,
#  'বিরুদ্ধে': 19,
#  'এক': 20,
#  'তিন': 21,
#  'আজ': 22,
#  'লাখ': 23,
#  'জন্য': 24,
#  'টাকা': 25,
#  'পরীক্ষা': 26,
#  'দাবি': 27,
#  'পুরস্কার': 28,
#  'সভা': 29,
#  'প্রথম': 30,
#  'আহত': 31,
#  'করতে': 32,
#  'ঢাকা': 33,
#  'বিতরণ': 34,
#  'পর': 35,
#  'কাল': 36,
#  'হাজার': 37,
#  'বন্ধ': 38,
#  'করে': 39,
#  'হচ্ছে': 40,
#  'বাংলাদেশ': 41,
#  'মামলা': 42,
#  'মৃত্যু': 43,
#  'ভর্তি': 44,
#  'পুলিশ': 45,
#  'দিন': 46,
#  'বিএনপির': 47,
#  'অনুষ্ঠান': 48,
#  'খালেদা': 49,
#  'শিক্ষা': 50,
#  'লাশ': 51,
#  'জন': 52,
#  'চট্টগ্রামে': 53,
#  'টাকার': 54,
#  'নারী': 55,
#  'কোটি': 56,
#  'নির্বাচন': 57,
#  'দেবে': 58,
#  'চার': 59,
#  'অ্যান্ড': 60,
#  'জনের': 61,
#  'শিশু': 62,
#  'অব': 63,
#  'নেতা': 64,
#  'পেলেন': 65,
#  'শতাংশ': 66,
#  'কমিটি': 67,
#  'পাঁচ': 68,
#  'করার': 69,
#  'সা': 70,
#  'করা': 71,
#  'মার্চ': 72,
#  'সরকার': 73,
#  'সিটি': 74,
#  'চট্টগ্রাম': 75,
#  'আহ্বান': 76,
#  'নেই': 77,
#  'প্রাথমিক': 78,
#  'করবে': 79,
#  'দিল': 80,
#  'হা': 81,
#  'য্যে': 82,
#  'বে': 83,
#  'ন': 84,
#  'টি': 85,
#  'জরিমানা': 86,
#  'নির্দেশ': 87,
#  'পরীক্ষার': 88,
#  'বছর': 89,
#  'জাতীয়': 90,
#  'পেল': 91,
#  'সময়': 92,
#  'যাবে': 93,
#  'সম্মেলন': 94,
#  'দিতে': 95,
#  'অনুষ্ঠিত': 96,
#  'বিএনপি': 97,
#  'তম': 98,
#  'অভিযোগ': 99,
#  'সদস্য': 100,
#  'ইসলামী': 101,
#  'সরকারি': 102,
#  'দিনের': 103,
#  'ঘটনায়': 104,
#  'চেয়ারম্যান': 105,
#  'হামলা': 106,
#  'বিশ্ববিদ্যালয়ে': 107,
#  'আরও': 108,
#  'উৎসব': 109,
#  'শেষ': 110,
#  'হত্যা': 111,
#  'বিশ্ববিদ্যালয়ের': 112,
#  'ঘণ্টা': 113,
#  'উদ্বোধন': 114,
#  'সাবেক': 115,
#  'সমাপনী': 116,
#  'লভ্যাংশ': 117,
#  'কাজ': 118,
#  'সংঘর্ষে': 119,
#  'হত্যার': 120,
#  'মেলা': 121,
#  'প্রধান': 122,
#  'ঘোষণা': 123,
#  'করল': 124,
#  'হতে': 125,
#  'নিয়ে': 126,
#  'প্রধানমন্ত্রীর': 127,
#  'দাবিতে': 128,
#  'কর্মসূচি': 129,
#  'মামলায়': 130,
#  'হলেন': 131,
#  'আলীগ': 132,
#  'করেছে': 133,
#  'সাত': 134,
#  'জব্দ': 135,
#  'কলেজ': 136,
#  'বিনা': 137,
#  'মানববন্ধন': 138,
#  'মামলার': 139,
#  'গঠন': 140,
#  'দল': 141,
#  'প্রকাশ': 142,
#  'স্কুল': 143,
#  'সমিতির': 144,
#  'সেপ্টেম্বর': 145,
#  'প্রদান': 146,
#  'চলাচল': 147,
#  'কর্মশালা': 148,
#  'জেলা': 149,
#  'দিবস': 150,
#  'এম': 151,
#  'জানুয়ারি': 152,
#  'শিক্ষার্থীদের': 153,
#  'উদ্যোগে': 154,
#  'আগস্ট': 155,
#  'স্থগিত': 156,
#  'নির্বাচনে': 157,
#  'কাছে': 158,
#  'দুটি': 159,
#  'বাংলাদেশের': 160,
#  'মে': 161,
#  'ফল': 162,
#  'পরীক্ষার্থীদের': 163,
#  'ঢাকার': 164,
#  'কেজি': 165,
#  'গ্রুপের': 166,
#  'দেশের': 167,
#  'আবার': 168,
#  'হলে': 169,
#  'বৃত্তি': 170,
#  'পরিষদের': 171,
#  'বিশেষ': 172,
#  'পারে': 173,
#  'চালু': 174,
#  'ডিসেম্বর': 175,
#  'ভারতে': 176,
#  'নভেম্বর': 177,
#  'পড়ে': 178,
#  'ঢাকায়': 179,
#  'স্মৃতি': 180,
#  'ক্লাব': 181,
#  'কলেজের': 182,
#  'আন্তর্জাতিক': 183,
#  'চৌধুরী': 184,
#  'সেরা': 185,
#  'ছাত্র': 186,
#  'প্রযুক্তি': 187,
#  'আবেদন': 188,
#  'শুনানি': 189,
#  'এপ্রিল': 190,
#  'ফেব্রুয়ারি': 191,
#  'করছে': 192,
#  'নির্বাচিত': 193,
#  'সেবা': 194,
#  'শিক্ষক': 195,
#  'জঙ্গি': 196,
#  'বাংলাদেশি': 197,
#  'সেমিনার': 198,
#  'আর': 199,
#  'বিজ্ঞান': 200,
#  'দলের': 201,
#  'নয়': 202,
#  'পদে': 203,
#  'চলচ্চিত্র': 204,
#  'হামলার': 205,
#  'মেডিকেল': 206,
#  'সাড়ে': 207,
#  'দিলেন': 208,
#  'সই': 209,
#  'সমাবেশ': 210,
#  'ইউনিভার্সিটি': 211,
#  'ক্রিকেট': 212,
#  'গুলি': 213,
#  'ট্রেন': 214,
#  'বাংলা': 215,
#  'জেএসসি': 216,
#  'আসামি': 217,
#  'জুলাই': 218,
#  'প্রার্থীর': 219,
#  'ওপর': 220,
#  'সভাপতি': 221,
#  'উপলক্ষে': 222,
#  'বাসের': 223,
#  'প্রতিবাদে': 224,
#  'সন্দেহে': 225,
#  'প্রধানমন্ত্রী': 226,
#  'সাড়ে': 227,
#  'ভোট': 228,
#  'প্রশিক্ষণ': 229,
#  'প্রদর্শনী': 230,
#  'ইউনিভার্সিটির': 231,
#  'আলোচনা': 232,
#  'ভারতীয়': 233,
#  'উত্তর': 234,
#  'জিয়া': 235,
#  'কর্মী': 236,
#  'সাক্ষাৎ': 237,
#  'শেখ': 238,
#  'কথা': 239,
#  'হরতাল': 240,
#  'থাকবে': 241,
#  'হয়ে': 242,
#  'মাদক': 243,
#  'অবৈধ': 244,
#  'বার্ষিক': 245,
#  'সাধারণ': 246,
#  'অক্টোবর': 247,
#  'কলেজে': 248,
#  'উন্নয়ন': 249,
#  'জিয়ার': 250,
#  'বেশি': 251,
#  'এস': 252,
#  'ট্রাকের': 253,
#  'গিয়ে': 254,
#  'সম্পাদক': 255,
#  'দায়ে': 256,
#  'পর্যন্ত': 257,
#  'মেয়র': 258,
#  'তথ্য': 259,
#  'বাড়ি': 260,
#  'তদন্ত': 261,
#  'বৈঠক': 262,
#  'নিতে': 263,
#  'অভিযোগে': 264,
#  'লীগ': 265,
#  'ব্র্যাক': 266,
#  'নগদ': 267,
#  'অ্যাওয়ার্ড': 268,
#  'কাদের': 269,
#  'কার্যক্রম': 270,
#  'আলীগের': 271,
#  'সম্মাননা': 272,
#  'শিশুর': 273,
#  'দিয়ে': 274,
#  'সব': 275,
#  'অস্ত্র': 276,
#  'বেতন': 277,
#  'পক্ষের': 278,
#  'মূল্যে': 279,
#  'আইন': 280,
#  'অংশ': 281,
#  'দেওয়া': 282,
#  'ইউনিটের': 283,
#  'খান': 284,
#  'যে': 285,
#  'শিশুদের': 286,
#  'বই': 287,
#  'ভারতের': 288,
#  'প্রার্থী': 289,
#  'পরিবারের': 290,
#  'গেল': 291,
#  'পুলিশের': 292,
#  'অনুদান': 293,
#  'ট্রাস্ট': 294,
#  'বাস': 295,
#  'হলো': 296,
#  'কারাদণ্ড': 297,
#  'করলেন': 298,
#  'কোটি': 299,
#  'মাস': 300,
#  'দুদকের': 301,
#  'ইয়াবা': 302,
#  'ক্লাবের': 303,
#  'যাত্রী': 304,
#  'ঈদের': 305,
#  'ঈদ': 306,
#  'রহমান': 307,
#  'পাচ্ছেন': 308,
#  'মডেল': 309,
#  'দেশে': 310,
#  'গান': 311,
#  'খালেদার': 312,
#  'টিভি': 313,
#  'কার্ড': 314,
#  'নেতাকে': 315,
#  'ব্যাংকে': 316,
#  'দিনে': 317,
#  'হক': 318,
#  'বিক্রি': 319,
#  'আলো': 320,
#  'বিশ্ববিদ্যালয়': 321,
#  'বছরের': 322,
#  'কর্মকর্তা': 323,
#  'শেয়ার': 324,
#  'ভবন': 325,
#  'ট্রেনের': 326,
#  'তৈরি': 327,
#  'সরকারের': 328,
#  'ঘটনায়': 329,
#  'এর': 330,
#  'ছয়': 331,
#  'ট্রাক': 332,
#  'পুনর্মিলনী': 333,
#  'প্রাণ': 334,
#  'ভাইস': 335,
#  'এবং': 336,
#  'আগুন': 337,
#  'স্মারক': 338,
#  'কৃষি': 339,
#  'মানুষ': 340,
#  'ব্যক্তি': 341,
#  'শ্রমিক': 342,
#  'গঠনের': 343,
#  'কমিটির': 344,
#  'সংঘর্ষ': 345,
#  'ইউপি': 346,
#  'অর্থ': 347,
#  'সমঝোতা': 348,
#  'ধাক্কায়': 349,
#  'আর্থিক': 350,
#  'বিশ্ব': 351,
#  'সাংসদ': 352,
#  'পক্ষে': 353,
#  'বিদ্যুৎ': 354,
#  'দুদক': 355,
#  'প্রতি': 356,
#  'আট': 357,
#  'প্রতিযোগিতা': 358,
#  'হামলায়': 359,
#  'চলছে': 360,
#  'শাহ': 361,
#  'এল': 362,
#  'নেওয়ার': 363,
#  'কেন্দ্র': 364,
#  'বছরে': 365,
#  'জুন': 366,
#  'চূড়ান্ত': 367,
#  'শপথ': 368,
#  'পাচার': 369,
#  'মৃত্যুবার্ষিকী': 370,
#  'দোকান': 371,
#  'মাহফিল': 372,
#  'সাহিত্য': 373,
#  'বাজারে': 374,
#  'চেষ্টা': 375,
#  'দেখা': 376,
#  'চেয়ে': 377,
#  'ডিজিটাল': 378,
#  'বঙ্গবন্ধুর': 379,
#  'পরিবেশ': 380,
#  'হাসপাতালে': 381,
#  'বা': 382,
#  'ব্যক্তির': 383,
#  'মহিলা': 384,
#  'পরিচালক': 385,
#  'হয়েছে': 386,
#  'যাত্রা': 387,
#  'নামে': 388,
#  'নেতার': 389,
#  'চেয়ারম্যান': 390,
#  'মা': 391,
#  'বিমানবন্দরে': 392,
#  'তাঁর': 393,
#  'রাজধানীতে': 394,
#  'আবদুল': 395,
#  'প্রায়': 396,
#  'বাতিল': 397,
#  'এসএসসি': 398,
#  'বার': 399,
#  'বোমা': 400,
#  'বঙ্গবন্ধু': 401,
#  'চ্যাম্পিয়ন': 402,
#  'দেওয়ার': 403,
#  'জামিন': 404,
#  'কবি': 405,
#  'কেন্দ্রে': 406,
#  'ছবি': 407,
#  'স্কুলের': 408,
#  'কেটে': 409,
#  'মতবিনিময়': 410,
#  'খেলা': 411,
#  'প্রস্তুতি': 412,
#  'বিচার': 413,
#  'করবেন': 414,
#  'বাংলাদেশে': 415,
#  'সম্পদ': 416,
#  'আগুনে': 417,
#  'যোগ': 418,
#  'স্মরণে': 419,
#  'পণ্য': 420,
#  'শাখা': 421,
#  'নির্মাণ': 422,
#  'রায়': 423,
#  'গ্রহণ': 424,
#  'জনকে': 425,
#  'বিতরণী': 426,
#  'পদ': 427,
#  'পাশে': 428,
#  'ভর্তির': 429,
#  'আওয়ামী': 430,
#  'চান': 431,
#  'হস্তান্তর': 432,
#  'জামায়াতের': 433,
#  'গ্রুপ': 434,
#  'মুক্তির': 435,
#  'দ্য': 436,
#  'ব্যাংকিং': 437,
#  'ককটেল': 438,
#  'ব্যবসায়ী': 439,
#  'সচিব': 440,
#  'মিডল্যান্ড': 441,
#  'ভেঙে': 442,
#  'তৃতীয়': 443,
#  'জমা': 444,
#  'আগে': 445,
#  'প্রশ্ন': 446,
#  'হয়': 447,
#  'খুন': 448,
#  'কাটা': 449,
#  'ছাত্রলীগ': 450,
#  'ইফতার': 451,
#  'আল': 452,
#  'নয়': 453,
#  'লীগের': 454,
#  'মার্কিন': 455,
#  'দগ্ধ': 456,
#  'শাহজালালে': 457,
#  'অভিযোগ': 458,
#  'ইউনিয়ন': 459,
#  'বিভাগের': 460,
#  'দেড়': 461,
#  'কে': 462,
#  'বন্ধের': 463,
#  'আসছে': 464,
#  'সনদ': 465,
#  'এনসিসি': 466,
#  'ঘোষণা': 467,
#  'নিষিদ্ধ': 468,
#  'হুমকি': 469,
#  'প্রাইম': 470,
#  'মাসে': 471,
#  'ফর': 472,
#  'সাউথ': 473,
#  'ইন্টারন্যাশনাল': 474,
#  'দ্বিতীয়': 475,
#  'পদক': 476,
#  'ব্যবস্থা': 477,
#  'এখন': 478,
#  'দুর্ঘটনায়': 479,
#  'সুযোগ': 480,
#  'উদ্যোগে': 481,
#  'ক্রীড়া': 482,
#  'তালিকা': 483,
#  'বিশ্ববিদ্যালয়ে': 484,
#  'পথে': 485,
#  'কারণে': 486,
#  'তারিখ': 487,
#  'পরিবর্তন': 488,
#  'কিছু': 489,
#  'সিমেন্ট': 490,
#  'মোহাম্মদ': 491,
#  'শিক্ষার্থী': 492,
#  'পদ্মা': 493,
#  'ভারত': 494,
#  'মাসের': 495,
#  'ইসলাম': 496,
#  'সার্ভিস': 497,
#  'কক্সবাজারে': 498,
#  'ট্রেনে': 499,
#  'পড়ে': 500,
#  'আবু': 501,
#  'অনুমোদন': 502,
#  'লাইনচ্যুত': 503,
#  'পূর্তি': 504,
#  'আজকের': 505,
#  'সোনার': 506,
#  'ফেরত': 507,
#  'চিঠি': 508,
#  'শিবিরের': 509,
#  'উদ্বোধন': 510,
#  'জাতীয়': 511,
#  'নাটক': 512,
#  'আইনজীবী': 513,
#  'চিটাগাং': 514,
#  'লাইফ': 515,
#  'আলী': 516,
#  'সাংস্কৃতিক': 517,
#  'প্রতিযোগিতা': 518,
#  'যাচ্ছে': 519,
#  'বিশ্ববিদ্যালয়ের': 520,
#  'ওষুধ': 521,
#  'চুরি': 522,
#  'গাড়ি': 523,
#  'চায়': 524,
#  'কল্যাণ': 525,
#  'স্বাস্থ্য': 526,
#  'ভাষার': 527,
#  'পরে': 528,
#  'নূর': 529,
#  'নর্থ': 530,
#  'শ্রমিকের': 531,
#  'স্থাপন': 532,
#  'নাম': 533,
#  'উৎপাদন': 534,
#  'হিসেবে': 535,
#  'রংপুরে': 536,
#  'কারখানা': 537,
#  'অভিযান': 538,
#  'কমিশন': 539,
#  'একজন': 540,
#  'দণ্ড': 541,
#  'সামনে': 542,
#  'নিখোঁজ': 543,
#  'হার': 544,
#  'চৌধুরী': 545,
#  'বেস্ট': 546,
#  'সড়ক': 547,
#  'ভূমিকা': 548,
#  'পালন': 549,
#  'স্ট্যান্ডার্ড': 550,
#  'শনিবার': 551,
#  'সংবর্ধনা': 552,
#  'হেলথ': 553,
#  'ডি': 554,
#  'সিলেটে': 555,
#  'গেছে': 556,
#  'আলোর': 557,
#  'টিকিট': 558,
#  'দিয়ে': 559,
#  'সেতুর': 560,
#  'এ': 561,
#  'কম্পিউটার': 562,
#  'আহমেদ': 563,
#  'নর্দান': 564,
#  'দেখুন': 565,
#  'টুর্নামেন্ট': 566,
#  'সালের': 567,
#  'বললেন': 568,
#  'সংসদের': 569,
#  'বর্ষের': 570,
#  'গ্যাস': 571,
#  'বিস্ফোরণে': 572,
#  'জঙ্গিবাদ': 573,
#  'থাকার': 574,
#  'ছিনতাই': 575,
#  'ডলার': 576,
#  'ঋণ': 577,
#  'বিসিএস': 578,
#  'রাজশাহী': 579,
#  'এরশাদ': 580,
#  'নারীর': 581,
#  'রাষ্ট্রপতি': 582,
#  'ফার্স্ট': 583,
#  'ফখরুল': 584,
#  'রাখার': 585,
#  'উদ্যাপন': 586,
#  'হয়নি': 587,
#  'সেন্টার': 588,
#  'গাজীপুরে': 589,
#  'ছাদ': 590,
#  'সিমেন্টের': 591,
#  'যুবকের': 592,
#  'সোনা': 593,
#  'হলো': 594,
#  'পর্ষদ': 595,
#  'স্বাক্ষর': 596,
#  'আদালত': 597,
#  'ইউনাইটেড': 598,
#  'আবেদনের': 599,
#  'বিদেশি': 600,
#  'প্রেসিডেন্ট': 601,
#  'ব্যবস্থাপনা': 602,
#  'বিক্ষোভ': 603,
#  'রিমান্ডে': 604,
#  'নির্বাহী': 605,
#  'কোর্স': 606,
#  'সংসদ': 607,
#  'খাতে': 608,
#  'ভাষা': 609,
#  'পরামর্শ': 610,
#  'শিবির': 611,
#  'দুস্থ': 612,
#  'চাল': 613,
#  'সঠিক': 614,
#  'ব্যবসায়ীর': 615,
#  'সোনাসহ': 616,
#  'জিপিএ': 617,
#  'ইলেকট্রনিকসের': 618,
#  'ঘর': 619,
#  'শহীদ': 620,
#  'জাল': 621,
#  'মালয়েশিয়া': 622,
#  'পরিবারকে': 623,
#  'ছুটি': 624,
#  'সেই': 625,
#  'বিজিবি': 626,
#  'পাওয়ার': 627,
#  'আলআরাফাহ্': 628,
#  'গাছ': 629,
#  'ফ্রি': 630,
#  'বন্ধুসভার': 631,
#  'খাদে': 632,
#  'তৈরির': 633,
#  'দাম': 634,
#  'একটি': 635,
#  'নিহতের': 636,
#  'জনগণের': 637,
#  'চট্টগ্রামের': 638,
#  'রেল': 639,
#  'বিজয়ীদের': 640,
#  'সদর': 641,
#  'রাষ্ট্রপতির': 642,
#  'হাসপাতাল': 643,
#  'সময়': 644,
#  'যুবক': 645,
#  'নির্বাচনী': 646,
#  'নম্বর': 647,
#  'মুক্তিযুদ্ধের': 648,
#  'এখানে': 649,
#  'নেতাদের': 650,
#  'আসর': 651,
#  'টিআইসিতে': 652,
#  'দ্রুত': 653,
#  'কর': 654,
#  'ফাউন্ডেশনের': 655,
#  'কারাগারে': 656,
#  'ওয়ার্ল্ড': 657,
#  'পরিদর্শন': 658,
#  'সিলেটের': 659,
#  'উচ্ছেদ': 660,
#  'সেনা': 661,
#  'পর্ব': 662,
#  'মাস্টার্স': 663,
#  'পূবালী': 664,
#  'ঐক্য': 665,
#  'দিনব্যাপী': 666,
#  'মুক্ত': 667,
#  'উন্নয়নে': 668,
#  'বহিষ্কার': 669,
#  'ক্রেডিট': 670,
#  'উপাচার্য': 671,
#  'পারেন': 672,
#  'প্রতিষ্ঠানের': 673,
#  'উপজেলা': 674,
#  'প্রতিবেদন': 675,
#  'চেক': 676,
#  'সাক্ষ্য': 677,
#  'কেন্দ্রের': 678,
#  'যুব': 679,
#  'রহমানের': 680,
#  'ধরে': 681,
#  'কারখানায়': 682,
#  'করায়': 683,
#  'কর্মকর্তাদের': 684,
#  'অতিরিক্ত': 685,
#  'কারা': 686,
#  'ভিসা': 687,
#  'সহকারী': 688,
#  'চতুর্থ': 689,
#  'ইনস্টিটিউট': 690,
#  'বিষয়ে': 691,
#  'লঞ্চ': 692,
#  'জাপার': 693,
#  'তুলে': 694,
#  'র\u200d্যাব': 695,
#  'এক্সিম': 696,
#  'বিস্ফোরণ': 697,
#  'পাসের': 698,
#  'এগিয়ে': 699,
#  'ধারা': 700,
#  'প্রিমিয়ার': 701,
#  'আসনে': 702,
#  'পেছাল': 703,
#  'ইউনিভার্সিটিতে': 704,
#  'অধিকার': 705,
#  'সম্পন্ন': 706,
#  'দিবসে': 707,
#  'লিখিত': 708,
#  'শান্তি': 709,
#  'সাদার্ন': 710,
#  'ডুবে': 711,
#  'গেছেন': 712,
#  'বিমান': 713,
#  'শীর্ষক': 714,
#  'কার': 715,
#  'এশিয়ার': 716,
#  'প্রতিষ্ঠানকে': 717,
#  'নিরাপত্তা': 718,
#  'সামিট': 719,
#  'ম্যাচ': 720,
#  'বিভাগ': 721,
#  'আই': 722,
#  'দুজন': 723,
#  'ছাড়া': 724,
#  'হওয়া': 725,
#  'বাণিজ্য': 726,
#  'কাজী': 727,
#  'জেলে': 728,
#  'মোবাইল': 729,
#  'যোগাযোগ': 730,
#  'পানি': 731,
#  'প্রতিবন্ধী': 732,
#  'ফেনীতে': 733,
#  'প্রকল্প': 734,
#  'শুধু': 735,
#  'রা': 736,
#  'ব্র্যান্ড': 737,
#  'প্রস্তাব': 738,
#  'জমি': 739,
#  'তথ্যমন্ত্রী': 740,
#  'সুপার': 741,
#  'ভবনের': 742,
#  'মামলায়': 743,
#  'শাখার': 744,
#  'আবৃত্তি': 745,
#  'রপ্তানি': 746,
#  'টেকনাফে': 747,
#  'কেন': 748,
#  'চালক': 749,
#  'বিবরণী': 750,
#  'মাধ্যমে': 751,
#  'মারা': 752,
#  'গিয়ে': 753,
#  'মানব': 754,
#  'ছাত্রলীগের': 755,
#  'শিক্ষার': 756,
#  'পুড়ে': 757,
#  'বিষয়ে': 758,
#  'দেওয়ায়': 759,
#  'সংগীত': 760,
#  'আইনের': 761,
#  'জয়ী': 762,
#  'ফিরে': 763,
#  'যায়': 764,
#  'সন্ত্রাসী': 765,
#  'ফরম': 766,
#  'ভোট': 767,
#  'দেখতে': 768,
#  'দক্ষিণ': 769,
#  'নানা': 770,
#  'সাংবাদিক': 771,
#  'সহায়তা': 772,
#  'ছেলের': 773,
#  'সিলেট': 774,
#  'মাঠে': 775,
#  'বি': 776,
#  'গুলিতে': 777,
#  'ছয়': 778,
#  'আছে': 779,
#  'সাজা': 780,
#  'ভিত্তিপ্রস্তর': 781,
#  'শুভেচ্ছা': 782,
#  'ডাকাতি': 783,
#  'বাজেট': 784,
#  'একাডেমি': 785,
#  'বাড়ল': 786,
#  'বরিশালে': 787,
#  'এশিয়া': 788,
#  'বাদ': 789,
#  'চিকিৎসা': 790,
#  'বিজয়ী': 791,
#  'রোটারি': 792,
#  'জামায়াত': 793,
#  'টেস্ট': 794,
#  'স্বাধীনতা': 795,
#  'কামাল': 796,
#  'রিট': 797,
#  'ট্রান্সকম': 798,
#  'আলম': 799,
#  'বড়': 800,
#  'কিনে': 801,
#  'ন্যাশনাল': 802,
#  'অগ্নিকাণ্ডে': 803,
#  'নাগরিক': 804,
#  'হামলায়': 805,
#  'বিভিন্ন': 806,
#  'বিসিএসের': 807,
#  'এএফসি': 808,
#  'হোসেন': 809,
#  'বিভাগীয়': 810,
#  'ক্যানসার': 811,
#  'অপসারণ': 812,
#  'আবাসিক': 813,
#  'ফুটবল': 814,
#  'বাহিনীর': 815,
#  'মনোনয়নপত্র': 816,
#  'হাজী': 817,
#  'কোনো': 818,
#  'এলাকায়': 819,
#  'অধ্যাপক': 820,
#  'নিন': 821,
#  'করেছেন': 822,
#  'নির্যাতনের': 823,
#  'তা': 824,
#  'সন্ত্রাস': 825,
#  'দরকার': 826,
#  'সিটির': 827,
#  'রুটে': 828,
#  'উদ্বেগ': 829,
#  'স্বীকার': 830,
#  'মাছ': 831,
#  'পরীক্ষায়': 832,
#  'সম্মান': 833,
#  'মন্ত্রণালয়ের': 834,
#  'সিডনিতে': 835,
#  'প্রতিবাদ': 836,
#  'চলবে': 837,
#  'মির্জা': 838,
#  'রওশন': 839,
#  'শিক্ষার্থীকে': 840,
#  'স্টার': 841,
#  'কর্মচারী': 842,
#  'কার্যালয়': 843,
#  'ধর্ষণের': 844,
#  'করুন': 845,
#  'ইনস্যুরেন্সের': 846,
#  'কর্মকর্তার': 847,
#  'যাত্রীর': 848,
#  'কক্সবাজার': 849,
#  'বোনাস': 850,
#  'বগি': 851,
#  'খুলনার': 852,
#  'জেনারেল': 853,
#  'কর্মকর্তাকে': 854,
#  'একক': 855,
#  'ইনস্যুরেন্স': 856,
#  'বিচারপতি': 857,
#  'সিরাজগঞ্জে': 858,
#  'ইসলামের': 859,
#  'ফ্রঁসেজে': 860,
#  'ফরাসি': 861,
#  'সেশন': 862,
#  'সুবিধা': 863,
#  'স্থাপনা': 864,
#  'গ্রাম': 865,
#  'আদেশ': 866,
#  'নেবে': 867,
#  'যমুনা': 868,
#  'ফাইন্যান্সের': 869,
#  'পর্দায়': 870,
#  'পরোয়ানা': 871,
#  'প্রশাসন': 872,
#  'চ্যানেল': 873,
#  'ছাড়া': 874,
#  'নিখোঁজ': 875,
#  'আফগানিস্তানে': 876,
#  'সমাজ': 877,
#  'আরোহী': 878,
#  'বাবা': 879,
#  'নিল': 880,
#  'দায়ে': 881,
#  'প্রতিমন্ত্রী': 882,
#  'চলন্ত': 883,
#  'মেয়র': 884,
#  'উপদেষ্টা': 885,
#  'বিদ্যালয়ের': 886,
#  'আবুল': 887,
#  'আমার': 888,
#  'পল্লী': 889,
#  'খুনিদের': 890,
#  'ব্যক্তিদের': 891,
#  'আনন্দ': 892,
#  'টুর্নামেন্টে': 893,
#  'শীতবস্ত্র': 894,
#  'টন': 895,
#  'লিমিটেডের': 896,
#  'স্কুলে': 897,
#  'চাপায়': 898,
#  'গঠিত': 899,
#  'হাত': 900,
#  'শিকার': 901,
#  'প্রবাসী': 902,
#  'ভাগ': 903,
#  'ফেসবুক': 904,
#  'সি': 905,
#  'আলোচনা': 906,
#  'শেরপুরে': 907,
#  'বিমানের': 908,
#  'লাভ': 909,
#  'তিনটি': 910,
#  'চারজন': 911,
#  'রমজানে': 912,
#  'মূল': 913,
#  'শতাধিক': 914,
#  'বিল': 915,
#  'বিধ্বস্ত': 916,
#  'ব্যবহার': 917,
#  'নির্মাণাধীন': 918,
#  'লতিফ': 919,
#  'করলে': 920,
#  'মাঝে': 921,
#  'প্রাইভেট': 922,
#  'কেন্দ্রীয়': 923,
#  'গোল্ডকাপ': 924,
#  'পার্টির': 925,
#  'পৌর': 926,
#  'যান': 927,
#  'কুমিল্লায়': 928,
#  'হিন্দু': 929,
#  'মালিক': 930,
#  'নজরুল': 931,
#  'বাধা': 932,
#  'সারা': 933,
#  'প্রতিরোধ': 934,
#  'পরিদর্শনে': 935,
#  'ইসি': 936,
#  'মারধর': 937,
#  'চেম্বারের': 938,
#  'জ্বালানি': 939,
#  'উদ্\u200cযাপন': 940,
#  'রাষ্ট্রদূত': 941,
#  'রোধে': 942,
#  'আসার': 943,
#  'পে': 944,
#  'দিচ্ছে': 945,
#  'এসিআই': 946,
#  'আনল': 947,
#  'সংস্কৃতি': 948,
#  'পাকিস্তানের': 949,
#  'প্রাক্তন': 950,
#  'প্রকাশিত': 951,
#  'ফখরুলসহ': 952,
#  'প্রকাশনা': 953,
#  'মিউচুয়াল': 954,
#  'জামায়াতের': 955,
#  'অফিস': 956,
#  'হাসিনা': 957,
#  'প্রকল্পের': 958,
#  'অপহরণের': 959,
#  'কুপিয়ে': 960,
#  'রাজশাহীতে': 961,
#  'কাজে': 962,
#  'শীর্ষ': 963,
#  'ফুড': 964,
#  'ঘরে': 965,
#  'বিদ্যুতের': 966,
#  'এটিএম': 967,
#  'তিনজন': 968,
#  'দিলে': 969,
#  'নিখোঁজের': 970,
#  'অর্জন': 971,
#  'প্রত্যাহারের': 972,
#  'কি': 973,
#  'ইতিহাস': 974,
#  'স্নাতক': 975,
#  'যাওয়া': 976,
#  'বন্দর': 977,
#  'বইমেলা': 978,
#  'ব্যবসা': 979,
#  'সমঝোতা': 980,
#  'খুলনা': 981,
#  'ধর্ষণ': 982,
#  'তহবিলে': 983,
#  'ফাউন্ডেশন': 984,
#  'ফের': 985,
#  'যা': 986,
#  'রক্ষায়': 987,
#  'জামায়াত': 988,
#  'সংগ্রহ': 989,
#  'জিয়া': 990,
#  'দাখিল': 991,
#  'লেনদেন': 992,
#  'বলতে': 993,
#  'থাকতে': 994,
#  'শিক্ষকদের': 995,
#  'ইন্টারনেট': 996,
#  'সিদ্ধান্ত': 997,
#  'প্রতিষ্ঠান': 998,
#  'নদী': 999,
#  'জখম': 1000,
#  ...}

# %%
def decode_sequence(input_seq):
    # Encode the input as state vectors.
    e_out, e_h, e_c = encoder_model.predict(input_seq)
    
    # Generate empty target sequence of length 1.
    target_seq = np.zeros((1,1))
    
    # Populate the first word of target sequence with the start word. 
    target_seq[0, 0] = target_word_index['sostok']

    stop_condition = False
    decoded_sentence = ''
    while not stop_condition:
      
        output_tokens, h, c = decoder_model.predict([target_seq] + [e_out, e_h, e_c])

        # Sample a token
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_token = reverse_target_word_index[sampled_token_index]
        
        if(sampled_token!='eostok'):
            decoded_sentence += ' '+sampled_token

        # Exit condition: either hit max length or find stop word.
        if (sampled_token == 'eostok'  or len(decoded_sentence.split()) >= (max_summary_len-1)):
            stop_condition = True

        # Update the target sequence (of length 1).
        target_seq = np.zeros((1,1))
        target_seq[0, 0] = sampled_token_index

        # Update internal states
        e_h, e_c = h, c

    return decoded_sentence

# %%
def seq2summary(input_seq):
    newString=''
    for i in input_seq:
        if((i!=0 and i!=target_word_index['sostok']) and i!=target_word_index['eostok']):
            newString=newString+reverse_target_word_index[i]+' '
    return newString

def seq2text(input_seq):
    newString=''
    for i in input_seq:
        if(i!=0):
            newString=newString+reverse_source_word_index[i]+' '
    return newString

# %%
for i in range(0,100):
    print("Review:",seq2text(x_val[i]))
    print("Original summary:",seq2summary(y_val[i]))
    print("Predicted summary:",decode_sequence(x_val[i].reshape(1,max_text_len)))
    print("\n")
# Out:
# Review: প্রতিবছরের মতো এবারও ট্রান্সকম ফুড লিমিটেড ভিসা জন্য শতাংশ ছাড় ক্যাম্পেইন চালু করেছে বাংলাদেশে সব ধরনের ভিসা দেশের সব হাট আউটলেটে এই সুবিধা পাবেন মার্চ থেকে আগামী জুন পর্যন্ত কার্যকর থাকবে এবং স্পেশাল ছাড়া সব নিয়মিত প্রযোজ্য হবে গুলশান সেন্টারে এবং আউটলেটে এক অনুষ্ঠানে ট্রান্সকম ফুড লিমিটেডের সিইও চৌধুরী ক্যাম্পেইনের উদ্বোধন করেন ট্রান্সকম পরিবারের পরিচিত মুখ অভিনেত্রী বন্যা মির্জা সংগীতশিল্পী এবং মডেল জান্নাতুল ফেরদৌসী অনুষ্ঠানে উপস্থিত ছিলেন বিজ্ঞপ্তি
# Original summary: ভিসা জন্য ট্রান্সকম শতাংশ ছাড়
# 1/1 [==============================] - 1s 956ms/step
# 1/1 [==============================] - 0s 262ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted summary:  দুই পক্ষের সংঘর্ষে আহত
#
#
# Review: রাজধানীর রুটে কাল মঙ্গলবার থেকে বিআরটিসির মহিলা বাস সার্ভিস চালুর নির্দেশ দিয়েছেন সড়ক পরিবহন সেতুমন্ত্রী ওবায়দুল কাদের আজ সোমবার এক সংবাদ বিজ্ঞপ্তিতে কথা জানিয়ে বলা হয় প্রতিদিন সকাল সাতটায় বিআরটিসির বাস কাউন্টার থেকে বাসটি নারী যাত্রীদের নিয়ে মতিঝিলের উদ্দেশে ছেড়ে যাবে বিকেল পাঁচটায় মতিঝিল থেকে আবার উদ্দেশে বাসটি এই রুটে চলাচলকারী নারী যাত্রীদের সুবিধার জন্য চালু করা হচ্ছে চট্টগ্রাম ইতিমধ্যে মন্ত্রীর নির্দেশে চালু করা হয়েছে মহিলা বাস সার্ভিস সার্ভিসের আওতায় দুটি বাস নগরের নিউমার্কেট থেকে চট্টগ্রাম বিশ্ববিদ্যালয় ক্যাম্পাস এবং কালুরঘাট হতে পর্যন্ত চলাচল করছে
# Original summary: রুটে মহিলা বাস সার্ভিস কাল থেকে
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# Predicted summary:  দুই পক্ষের সংঘর্ষে আহত
#
#
# Review: জামালপুর শহরে আওয়ামী লীগের মেয়র প্রার্থীর নির্বাচনী কার্যালয়ে ভাঙচুর প্রচারণায় বাধা সৃষ্টির অভিযোগে বিএনপির মেয়র প্রার্থীর বিরুদ্ধে মামলা করা হয়েছে ঘটনায় গত বুধবার রাতে পুলিশ জেলা বিএনপির এক নেতাসহ পাঁচজনকে গ্রেপ্তার করেছে পুলিশ জানায় শহরের এলাকায় আওয়ামী লীগের মেয়র প্রার্থী মির্জা আলমের নির্বাচনী কার্যালয় ভাঙচুর তাঁর প্রচারণায় বাধা সৃষ্টির অভিযোগে বুধবার রাতে বিএনপির মেয়র প্রার্থী মো আলীর নামে থানায় একটি মামলা হয়েছে শহর যুবলীগের সাধারণ সম্পাদক রহমান ওরফে মামলাটি করেন ওই রাতেই জেলা বিএনপির আইনবিষয়ক সম্পাদক রবিউল আলম বিএনপির কর্মী সোহেল পাঁচজনকে গ্রেপ্তার করে পুলিশ
# Original summary: বিএনপির জনের নামে মামলা গ্রেপ্তার
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# Predicted summary:  দুই পক্ষের সংঘর্ষে আহত
#
#
# Review: চট্টগ্রাম জেলা শিল্পকলা একাডেমীর উদ্যোগে দিনব্যাপী অক্টোবর শুরু হচ্ছে উৎসব উপলক্ষে আগামী নভেম্বর পর্যন্ত শিল্পকলার মিলনায়তনে প্রতিদিন সন্ধ্যা সাতটায় নাটক পরিবেশন করবে বিভিন্ন নাটকের দল পাশাপাশি প্রতিদিন সন্ধ্যা ছয়টা থেকে নাটক আবৃত্তি সংগীত হবে উৎসবে নাট্য সম্প্রদায়ের চান মানুষ লোক কথা থিয়েটার চট্টগ্রামের থিয়েটার ইউনিটের স্বপ্ন স্বদেশ নাট্য সম্প্রদায়ের কোর্ট মার্শাল গন্তব্য নাট্য সম্প্রদায়ের অতি সাধারণ চিকিৎসক নাটক হবে বিজ্ঞপ্তি
# Original summary: দিনব্যাপী অক্টোবর শুরু
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted summary:  দুই পক্ষের সংঘর্ষে আহত
#
#
# Review: এক্সিম ব্যাংকের মতিঝিল আগ্রাবাদ গুলশান শাখার ব্যাংকিং পরিচালনা করার জন্য ব্যাংকিং পরিচালনা সফটওয়্যার চালু করা হয়েছে গত রোববার ব্যাংকের প্রধান কার্যালয়ে অনুষ্ঠিত এক অনুষ্ঠানে এই সফটওয়্যার চালু করা হয় এতে প্রধান অতিথি হিসেবে উপস্থিত ছিলেন এক্সিম ব্যাংকের ব্যবস্থাপনা পরিচালক প্রধান নির্বাহী মোহাম্মদ হায়দার আলী মিয়া এবং বিশেষ অতিথি হিসেবে উপস্থিত ছিলেন সফটওয়্যার প্রতিষ্ঠান ইনফরমেশন লিমিটেডের ব্যবস্থাপনা পরিচালক প্রধান নির্বাহী মাহমুদ হোসাইন সময় আরও উপস্থিত ছিলেন এক্সিম ব্যাংকের উপব্যবস্থাপনা উভয় প্রতিষ্ঠানের ঊর্ধ্বতন কর্মকর্তারা বিজ্ঞপ্তি
# Original summary: এক্সিম ব্যাংকে ব্যাংকিং নতুন
# 1/1 [==============================] - 0s 119ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# Predicted summary:  দুই পক্ষের সংঘর্ষে আহত
#
#
# Review: মুন্সিগঞ্জের মাওয়া থেকে আজ মঙ্গলবার সকালে বিপুল পরিমাণ থ্রি পিস কাপড় জব্দ করেছেন শুল্ক গোয়েন্দারা কর্মকর্তাদের ভাষ্য প্রায় তিন কোটি টাকা মূল্যের পণ্যগুলো ভারত থেকে অবৈধভাবে দেশে আনা হয়েছে শুল্ক পক্ষ থেকে আজ মঙ্গলবার সকালে গণমাধ্যমে পাঠানো মোবাইল ফোনের খুদেবার্তায় তথ্য জানানো হয় তথ্যমতে গোপন তথ্যের ভিত্তিতে শুল্ক গোয়েন্দা গার্ড যৌথভাবে অভিযান চালায় অভিযানে একটি ট্রাক থেকে ওই থ্রি পিস কাপড় জব্দ করা হয় ঘটনায় কাউকে আটক করা যায়নি শুল্ক ভাষ্য পণ্যগুলো ভারত সীমান্ত দিয়ে চোরাই পথে বাংলাদেশে এসেছে পণ্যের গন্তব্য ছিল ঢাকা বিষয়টি তদন্ত করা হবে
# Original summary: তিন কোটি টাকার অবৈধ জব্দ
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# Predicted summary:  দুই পক্ষের সংঘর্ষে আহত
#
#
# Review
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# Predicted summary:  দুই পক্ষের সংঘর্ষে আহত
#
#
# Review: চতুর্থ দিন শেষে উইকেট হাতে রেখে এরই মধ্যে শ্রীলঙ্কার রান শ্রীলঙ্কার দ্বিতীয় শেষ পর্যন্ত কত দূর যাবে কত লক্ষ্য পাবে বাংলাদেশ এই মাঠে সর্বোচ্চ রান করে জয়ের শ্রীলঙ্কার তবে দলের ক্ষেত্রে বড় জয়ের
# Original summary: করে
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# Predicted summary:  দুই পক্ষের সংঘর্ষে আহত
#
#
# Review: হাউস অব স্পিকার ডি আগামীকাল শুক্রবার ঢাকায় আসছেন জাতীয় সংসদের স্পিকার শিরীন শারমিন চৌধুরীর আমন্ত্রণে তিনি ঢাকায় আসছেন বলে সংসদ সচিবালয় সূত্র জানায় সংসদ সচিবালয়ের অতিরিক্ত সচিব প্রণব চক্রবর্তী জানান ডি একুশে ফেব্রুয়ারি প্রথম প্রতি শ্রদ্ধা জানাতে কেন্দ্রীয় শহীদ মিনারে যাবেন এরপর তিনি সংসদ ভবনে স্পিকার শিরীন শারমিন চৌধুরীর সঙ্গে সৌজন্য সাক্ষাৎ করবেন এবং সংসদ ভবন ঘুরে ওই রাতে তিনি ঢাকা ত্যাগ করবেন
# Original summary: অব ঢাকায় আসছেন কাল
# 1/1 [==============================] - 0s 134ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# Predicted summary:  দুই পক্ষের সংঘর্ষে আহত
#
#
# Review: প্রশাসনিক আপিল ট্রাইব্যুনালের সদস্য হিসেবে যশোরের জেলা দায়রা জজ মো গোলাম নিয়োগ দেওয়া হয়েছে তাঁকে প্রশাসনিক আপিল ট্রাইব্যুনালের নিয়োগ দেওয়া হয়েছে আইন বিচার মন্ত্রণালয়ের আইন বিচার বিভাগ অক্টোবর বিজ্ঞপ্তি জারি করে গত সেপ্টেম্বর প্রথম প্রশাসনিক আপিল ট্রাইব্যুনাল সদস্যের অভাবে শিরোনামে প্রতিবেদন প্রকাশিত হয় আইন মন্ত্রণালয়ের বিজ্ঞপ্তিতে বলা হয় সুপ্রিম কোর্টের সঙ্গে যশোরের জেলা দায়রা জজ মো গোলাম ঢাকার প্রশাসনিক আপিল ট্রাইব্যুনালের নিয়োগ করা হয়েছে এতে তাঁকে দিয়ে অবিলম্বে বদলি করা কর্মস্থলে যোগদান করতে বলা হয়
# Original summary: জেলা সদস্য
# 1/1 [==============================] - 0s 155ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# Predicted summary:  দুই পক্ষের সংঘর্ষে আহত
#
#
# Review: আওয়ামী লীগের সাধারণ সম্পাদক সৈয়দ আশরাফুল ইসলামকে স্থানীয় সরকার মন্ত্রণালয় থেকে সরিয়ে দেওয়ার কারণ সরকারের স্পষ্ট করা উচিত বলে মনে করছে বিএনপি দলটির মুখপাত্র আসাদুজ্জামান রিপন আজ শনিবার দুপুরে এক সংবাদ সম্মেলনে কথা বলেন সৈয়দ অপসারণের বিষয়ে এক প্রশ্নের জবাবে আসাদুজ্জামান বলেন এটি সরকারের একান্ত অভ্যন্তরীণ বিষয় বিষয় নিয়ে তিনি কিছু বলতে চান না তবে কী কারণে তাঁকে সরিয়ে দেওয়া হলো সরকারের উচিত তা জনগণের কাছে স্পষ্ট করা আসাদুজ্জামান বলেন ব্যক্তিগত তিনি মনে করেন একজন মানুষ যখন হন তখন তাঁর সমালোচনা করা ঠিক নয়
# Original summary: কারণ করা বিএনপি
# 1/1 [==============================] - 0s 152ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# Predicted summary:  দুই পক্ষের সংঘর্ষে আহত
#
#
# Review
# 1/1 [==============================] - 0s 144ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted summary:  দুই পক্ষের সংঘর্ষে আহত
#
#
# Review: ফার্স্ট ইন্টারন্যাশনাল কনফারেন্স অন বিজনেস অ্যান্ড করছে ফার্স্ট সিকিউরিটি ইসলামী ব্যাংক লিমিটেড ব্র্যাক বিশ্ববিদ্যালয়ের উদ্যোগে সেপ্টেম্বর ঢাকার হোটেল এই কনফারেন্স অনুষ্ঠিত হবে উপলক্ষে ব্যাংকের প্রধান কার্যালয়ে আয়োজকদের হাতে চেক তুলে দেন ব্যাংকের ব্যবস্থাপনা পরিচালক সৈয়দ ওয়াসেক মো আলী আরও উপস্থিত ছিলেন ব্যাংকের অতিরিক্ত ব্যবস্থাপনা পরিচালক সৈয়দ হাবিব হাসনাত ব্র্যাক বিশ্ববিদ্যালয়ের অধ্যাপক মামুন হাবিব অধ্যাপক হাসান চৌধুরী বিজ্ঞপ্তি
# Original summary: আন্তর্জাতিক ফার্স্ট সিকিউরিটি ইসলামী ব্যাংক
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# Predicted summary:  দুই পক্ষের সংঘর্ষে আহত
#
#
# Review: প্রস্তাবিত শিক্ষা মাধ্যমে সরকার মাদ্রাসার ধ্বংস করতে চায় বলে দাবি করেছেন হেফাজতে ইসলামের আমির শাহ আহমদ শফী তিনি বলেন কয়েকটি সংস্থার লোকজন কারও কারও কাছে সরকারি স্বীকৃতি দেওয়ার দিয়ে পায়ে গতকাল বুধবার বাংলাদেশ মাদ্রাসা শিক্ষা বোর্ডের শীর্ষস্থানীয় কর্মকর্তাদের এক বৈঠকে বোর্ডের সভাপতি শাহ আহমদ শফী এসব কথা বলেন গণমাধ্যমে হেফাজতে ইসলামের পাঠানো এক সংবাদ বিজ্ঞপ্তিতে আহমদ বক্তব্য তুলে ধরা হয় চট্টগ্রামের উলুম হাটহাজারী মাদ্রাসার কার্যালয়ে বৈঠকে আহমদ শফী অভিযোগ করেন এই তৎপরতা মাদ্রাসার জনতা সফল হতে দেবে না
# Original summary: সরকার
# 1/1 [==============================] - 0s 139ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# Predicted summary:  দুই পক্ষের সংঘর্ষে আহত
#
#
# Review: কুষ্টিয়ার মিরপুর উপজেলায় গত শুক্রবার সন্ধ্যায় বাসের পিষ্ট হয়ে গোলাম কিবরিয়া নামের একজন ট্রাকচালক নিহতের ঘটনায় থানায় মামলা হয়েছে গতকাল শনিবার মিরপুর থানার ভারপ্রাপ্ত কর্মকর্তা ওসি কাজী জালাল উদ্দীন বলেন শুক্রবার রাত সাড়ে টার দিকে নিহত ব্যক্তির বড় ভাই হোসেন বাদী হয়ে মামলাটি করেন মামলায় বাসের চালক সুজন আলী চালকের আসামি করা হয়েছে সুজন আলীকে পুলিশ গ্রেপ্তার করে দুপুরে আদালতের মাধ্যমে কারাগারে পাঠিয়েছে তাঁর বাড়ি কুষ্টিয়ার দৌলতপুর উপজেলার গ্রামে তবে চালকের নাম জানা যায়নি তিনি পলাতক রয়েছেন ওসি আরও জানান নিহত লাশ কুষ্টিয়া জেনারেল হাসপাতালে শেষে পরিবারের কাছে হস্তান্তর করা হয়েছে
# Original summary: নিহতের ঘটনায় মামলা আসামি
# 1/1 [==============================] - 0s 134ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# Predicted summary:  দুই পক্ষের সংঘর্ষে আহত
#
#
# Review: পাকিস্তানের অভ্যন্তরীণ বিষয়ে যুক্তরাষ্ট্র বলে অভিযোগ তুরস্কের প্রেসিডেন্ট তুরস্কের প্রতিবেশী দেশ এক সপ্তাহের বেশি সময় ধরে উত্তেজনা চলছে সরকারবিরোধী বিক্ষোভ সংঘর্ষে এখন পর্যন্ত অন্তত জন মারা গেছেন টুইট করছেন মার্কিন প্রেসিডেন্ট ডোনাল্ড ট্রাম্প আর তীব্র হয়েছে গতকাল রাষ্ট্রীয় ভ্রমণ শুরু করেছেন এর আগে তিনি সাংবাদিকদের বলেন কিছু দেশ বিশেষ করে যুক্তরাষ্ট্র ইরানের অভ্যন্তরীণ বিষয়ে হস্তক্ষেপ করছে এটা আমাদের কাছে গ্রহণযোগ্য নয় প্রেসিডেন্ট বলেন তারা যুক্তরাষ্ট্র বিভিন্ন দেশের জনগণকে একজনের বিরুদ্ধে লাগিয়ে দিচ্ছে
# Original summary: নিয়ে
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# Predicted summary:  দুই পক্ষের সংঘর্ষে আহত
#
#
# Review: প্রিয় পরীক্ষার্থী বিষয়ভিত্তিক সমস্যা পরীক্ষা নিয়ে বিশেষ কোনো প্রশ্ন থাকলে অবশ্যই নাম বিদ্যালয়ের নাম ঠিকানাসহ লিখে পাঠাও উত্তর ছাপা হবে পড়াশোনা পাতায় উত্তর দেবেন অভিজ্ঞ শিক্ষকবৃন্দ প্রশ্ন পাঠাবে নিচের প্রথম আলো সিএ ভবন কাজী নজরুল ইসলাম অ্যাভিনিউ কারওয়ান বাজার ঢাকা অথবা ইমেইল porasonaprothomaloinfo
# Original summary: প্রাথমিক শিক্ষা সমাপনী জেএসসি পরীক্ষার্থীদের জন্য
# 1/1 [==============================] - 0s 146ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted summary:  দুই পক্ষের সংঘর্ষে আহত
#
#
# Review: বিশ্বজুড়ে স্লোগান সামনে রেখে নর্থ সাউথ ইউনিভার্সিটি এনএসইউ মহান একুশে ফেব্রুয়ারি আন্তর্জাতিক মাতৃভাষা দিবস উপলক্ষে গত সোমবার দুদিনব্যাপী নানা কর্মসূচি হাতে নেয় সোমবার বিকেলে আন্তর্জাতিক মাতৃভাষা দিবসের আলোচনা সভায় প্রধান অতিথি ছিলেন তথ্যমন্ত্রী হাসানুল হক ইনু এতে প্রধান বক্তা ছিলেন আহমদ রফিক এবং সম্মানিত অতিথি ছিলেন এনএসইউ ট্রাস্টি বোর্ডের চেয়ারম্যান আজিম উদ্দিন আহমেদ এনএসইউ ট্রাস্টি বোর্ডের সদস্য মো শাহজাহান আলোচনা সভা শেষে অতিথিরা প্রদর্শনী ঘুরে দেখেন পরদিন ফেব্রুয়ারি সকালে বিশ্ববিদ্যালয়ের পক্ষে কেন্দ্রীয় শহীদ মিনার এবং এরপর নর্থ সাউথ ইউনিভার্সিটির ক্যাম্পাস শহীদ মিনারে অর্পণ করা হয় বিজ্ঞপ্তি
# Original summary: নর্থ শীর্ষক অনুষ্ঠান
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# Predicted summary:  দুই পক্ষের সংঘর্ষে আহত
#
#
# Review: তথ্যমন্ত্রী হাসানুল হক ইনু বলেছেন বিএনপির চেয়ারপারসন খালেদা জিয়া যদি জামায়াতের সঙ্গ ত্যাগ না করেন এবং চলমান সহিংস আন্দোলনের পক্ষে সাফাই করেন তাহলে তিনি দেশের জন্য হুমকি হয়ে থাকবেন গতকাল বৃহস্পতিবার সচিবালয়ে নিজ মন্ত্রণালয়ে এক সংবাদ সম্মেলনে তথ্যমন্ত্রী এসব কথা বলেন তিনি বলেন খালেদা জিয়া যে আন্দোলনের পক্ষে কথা বলছেন তাতে আমাদের মনে হয়েছে তাঁর অবস্থান করেননি আগের দিন সংবাদ সম্মেলন করে খালেদা জিয়ার দেওয়া বক্তব্যের জবাব দিতে সংবাদ সম্মেলনের আয়োজন করেন তথ্যমন্ত্রী
# Original summary: জামায়াত না খালেদা হুমকি হয়ে তথ্যমন্ত্রী
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 21ms/step
# Predicted summary:  দুই পক্ষের সংঘর্ষে আহত
#
#
# Review
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# Predicted summary:  দুই পক্ষের সংঘর্ষে আহত
#
#
# Review: টাঙ্গাইলের বেতনভাতা বৃদ্ধির দাবিতে উইমেন্স মেডিকেল কলেজ হাসপাতালের চিকিৎসকেরা কর্মবিরতি পালন করেছেন গতকাল বুধবার সকাল টা থেকে দুপুর টা পর্যন্ত তাঁরা কর্মসূচি পালন করেন সংশ্লিষ্ট সরকার সম্প্রতি চিকিৎসকদের বেতনভাতা বৃদ্ধির ঘোষণা দেয় কিন্তু সেই ঘোষণা অনুযায়ী উইমেন্স মেডিকেল কলেজ অ্যান্ড হাসপাতালের চিকিৎসকদের বর্ধিত বেতনভাতা দেওয়া শুরু হয়নি
# Original summary: বেতন দাবিতে
# 1/1 [==============================] - 0s 143ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# Predicted summary:  দুই পক্ষের সংঘর্ষে আহত
#
#
# Review: এনসিসি ব্যাংক লিমিটেড সম্প্রতি বাংলাদেশ ব্যাংকের সঙ্গে রপ্তানিমুখী বস্ত্র টেক্সটাইল পণ্য এবং লক্ষ্যে গ্রিন তহবিলে চুক্তি স্বাক্ষর করেছে এনসিসি ব্যাংকের ব্যবস্থাপনা পরিচালক সিইও গোলাম হাফিজ আহমেদ এবং বাংলাদেশ ব্যাংকের ফিন্যান্স বিভাগের মহাব্যবস্থাপক কুমার বিশ্বাস চুক্তিতে স্বাক্ষর করেন সময় বাংলাদেশ ব্যাংকের ডেপুটি গভর্নর এস কে সুর চৌধুরী প্রধান অতিথি হিসেবে উপস্থিত ছিলেন বিজ্ঞপ্তি
# Original summary: এনসিসি ব্যাংক বাংলাদেশ ব্যাংকের মধ্যে চুক্তি
# 1/1 [==============================] - 0s 139ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted summary:  দুই পক্ষের সংঘর্ষে আহত
#
#
# Review: সাবেক গৃহায়ণ গণপূর্ত প্রতিমন্ত্রী আব্দুল মান্নান খানের একান্ত সহকারী ইলিয়াস খান বিরুদ্ধে অনুসন্ধানের সিদ্ধান্ত নিয়েছে দুদক আজ বৃহস্পতিবার বিকেলে দুদক কর্তৃপক্ষ সিদ্ধান্ত নেয় দুদকের উপপরিচালক প্রণব কুমার ভট্টাচার্য প্রথম আলোকে জানান অভিযোগের অনুসন্ধানের জন্য কর্মকর্তা নিয়োগ করা হবে দুদক সূত্রে জানা যায় ইলিয়াস খান মান্নান খানের একান্ত সহকারী শত কোটি টাকার সম্পদ অর্জন করেছেন এর আগে গত জানুয়ারি থেকে আব্দুল মান্নান খানের দুদকের অনুসন্ধান চলছে তাঁকে বিষয়ে করেছে দুদক
# Original summary: সাবেক বিরুদ্ধে সিদ্ধান্ত দুদকের
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted summary:  দুই পক্ষের সংঘর্ষে আহত
#
#
# Review: ভারতের উত্তর প্রদেশের শহরের একটি ট্রাকের সংঘর্ষে অন্তত জন নিহত হয়েছে নিহত ব্যক্তিদের মধ্যে জন শিশু শিক্ষার্থী রয়েছে বলে আশঙ্কা করা হচ্ছে আজ বৃহস্পতিবার সকালে দুর্ঘটনা ঘটে এই ঘটনায় কমপক্ষে জন আহত হয়েছে এর মধ্যে জনের অবস্থা আশঙ্কাজনক টাইমস অব ইন্ডিয়া অনলাইনের খবরে কথা জানানো হয় প্রত্যক্ষদর্শীরা জানান বাসটি থেকে হতাহত ব্যক্তিদের উদ্ধার করতে প্রায় এক ঘণ্টা সময় লাগে নিহত স্কুল শিক্ষার্থীরা পাবলিক স্কুলের শিক্ষার্থী আহত ব্যক্তিদের হাসপাতালে ভর্তি করা হয়েছে আবহাওয়ার কারণে জেলা ম্যাজিস্ট্রেট তিন দিন স্কুল ছুটির ঘোষণা দিলেও পাবলিক আজ খোলা ছিল
# Original summary: ভারতে ট্রাকের সংঘর্ষে নিহত
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# Predicted summary:  দুই পক্ষের সংঘর্ষে আহত
#
#
# Review: বাংলাদেশে নিযুক্ত যুক্তরাষ্ট্রের রাষ্ট্রদূত মার্শা বার্নিকাট বলেছেন যুক্তরাষ্ট্র বাংলাদেশের মধ্যে সব ধরনের বাণিজ্য পাশাপাশি সহযোগিতা সম্পর্ক ভবিষ্যতে আরও বৃদ্ধি পাবে স্পিকার শিরীন শারমিন চৌধুরীর সঙ্গে তাঁর কার্যালয়ে সাক্ষাৎকালে গতকাল রোববার তিনি কথা বলেন জাতীয় সংসদ সচিবালয়ের এক সংবাদ বিজ্ঞপ্তিতে বলা হয় সাক্ষাৎকালে রাষ্ট্রদূত বাংলাদেশের উন্নয়নে যুক্তরাষ্ট্রের সহযোগিতা অব্যাহত রাখার আশ্বাস দেন পাশাপাশি জলবায়ু পরিবর্তনের বিরূপ প্রভাব মোকাবিলায় দুটি দেশের কাজ করারও সুযোগ আছে বলে তিনি উল্লেখ করেন সময় তাঁরা দ্বিপক্ষীয় সম্পর্ক কাজ করার ওপর করেন বাংলাদেশের প্রথম নারী স্পিকার নির্বাচিত হওয়ায় মার্কিন রাষ্ট্রদূত শুরুতেই শিরীন শারমিন চৌধুরীকে অভিনন্দন জানান
# Original summary: রাখার দিলেন রাষ্ট্রদূত
# 1/1 [==============================] - 0s 121ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted summary:  দুই পক্ষের সংঘর্ষে আহত
#
#
# Review: শেয়ার মার্কেটের সঙ্গে সম্পর্কিত নিবন্ধিত পাবলিক লিমিটেড কোম্পানি ঢাকা স্টক এক্সচেঞ্জ লিমিটেড ডিএসই আইটি সমাধান সেবা দেওয়া টেক ওয়ান গ্লোবাল প্রা লিমিটেডের মধ্যে মাইক্রোসফট এন্টারপ্রাইজ চুক্তি সম্পাদিত হয়েছে চুক্তির আওতায় ডিএসই সহজে মাইক্রোসফটের সফটওয়্যার লাইসেন্স কিনতে পারবে চুক্তির লক্ষ্য আইটি সমাধান সেবার ক্ষেত্রে দ্রুত প্রযুক্তির সঙ্গে চলতে সহায়তা করা এই অন্যতম উদ্যোক্তা টেক ওয়ান সিওও বিজ্ঞপ্তি
# Original summary: ঢাকা চুক্তি
# 1/1 [==============================] - 0s 141ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# Predicted summary:  দুই পক্ষের সংঘর্ষে আহত
#
#
# Review: পার্থ ব্রিজ
# Original summary: পক্ষে তিন
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# Predicted summary:  দুই পক্ষের সংঘর্ষে আহত
#
#
# Review: মে বুধবার বিকেলে ঝিনাইদহ জেলার গ্রামের প্রায় এতিম মধ্যে বিতরণ করে নবগঠিত শেখ কামাল টেক্সটাইল ইঞ্জিনিয়ারিং কলেজ বন্ধুসভা ইফতার বিতরণ অনুষ্ঠিত হয়েছে আমাদের শেখ কামাল টেক্সটাইল ইঞ্জিনিয়ারিং কলেজ ক্যাম্পাস প্রাঙ্গণে বন্ধুসভার সব বন্ধু প্রত্যেক ছাত্রের হাতে ইফতারের প্যাকেট তুলে দেয় রমজান মাসে এই ভালো কাজ দেখে ক্যাম্পাসের আশপাশের স্থানীয় মানুষ বন্ধুসভা ব্যাপারে জানতে আগ্রহ প্রকাশ করেন তারা জেনে খুব খুশি হয় প্রথম আলো বন্ধুসভা নামের একটি পাঠক সংগঠন আছে যা মানবিক এবং মানবতার কল্যাণে কাজ করে আহ্বায়ক সদস্য শেখ কামাল টেক্সটাইল ইঞ্জিনিয়ারিং কলেজ বন্ধুসভা
# Original summary: শেখ কামাল কলেজ বন্ধুসভার ইফতার বিতরণ
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted summary:  দুই পক্ষের সংঘর্ষে আহত
#
#
# Review: ভোলার উপজেলার ইউনিয়নে আট বছরের এক শিশু গত বুধবার ধর্ষণের শিকার হয়েছে ঘটনার তিন দিন পর অবস্থায় তাকে শুক্রবার বিকেলে সদর হাসপাতালে ভর্তি করা হয় এদিকে অভিযুক্ত ব্যক্তি আওয়ামী লীগের স্থানীয় কর্মী হওয়ায় আইনি সহায়তা না নিতে শিশুটির পরিবারকে নানা হুমকি দেওয়া হচ্ছে বলে অভিযোগ পাওয়া গেছে থানার ওসি গাজী শহিদুর জানান মামলা না করতে শিশুটির পরিবারকে নানা হুমকি দেওয়া হচ্ছে সদর হাসপাতালের আবাসিক চিকিৎসা কর্মকর্তা সাইদুল বাশার বলেন ধর্ষণের নষ্ট হওয়ার আগেই পরীক্ষানিরীক্ষা করা দরকার তবে পুলিশ অনুমতি না দেওয়া পর্যন্ত পরীক্ষার এগিয়ে নেওয়া যাচ্ছে না
# Original summary: আট বছরের শিশুকে ধর্ষণ মামলা না করতে হুমকি
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# Predicted summary:  দুই পক্ষের সংঘর্ষে আহত
#
#
# Review: চট্টগ্রাম নগরের বায়েজিদ আরেফিন নগর এলাকায় আধিপত্য কেন্দ্র করে দুই পক্ষে সংঘর্ষ হয়েছে সময় দোকান ভাঙচুর করা হয় সংঘর্ষের সময় দুই পক্ষের লোকজন দেশীয় অস্ত্র ব্যবহার করেন গতকাল শুক্রবার সন্ধ্যা সাড়ে সাতটার দিকে ঘটনা ঘটে এতে কয়েকজন আহত হয়েছেন পুলিশ সূত্র জানায় এলাকার গ্রুপ গ্রুপের মধ্যে ভাঙচুরের ঘটনা ঘটে ঘটনায় আহত তিনজনকে চট্টগ্রাম মেডিকেল কলেজ হাসপাতালে ভর্তি করা হয়েছে তাঁরা হলেন সোহেল কবির বাকলিয়া থানার ভারপ্রাপ্ত কর্মকর্তা ওসি মো মহসিন বলেন এলাকায় আধিপত্য কেন্দ্র করে গ্রুপের মধ্যে ভাঙচুর হয়েছে হামলায় জড়িত ব্যক্তিদের গ্রেপ্তারের চেষ্টা চলছে
# Original summary: চট্টগ্রামে নিয়ে দুই পক্ষে সংঘর্ষ
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# Predicted summary:  দুই পক্ষের সংঘর্ষে আহত
#
#
# Review: ফেনী জেলার সব সরকারিবেসরকারি হাসপাতাল শতভাগ এলাকা ঘোষণা করা হয়েছে গত ডিসেম্বর ফেনীতে দ্রব্য ব্যবহার বন্ধের ওপর স্বাস্থ্য বিভাগের এক কর্মশালায় সিদ্ধান্ত ঘোষণা করা হয়েছে জেলা শিল্পকলা একাডেমি মিলনায়তনে আয়োজিত কর্মশালায় প্রধান অতিথি ছিলেন স্বাস্থ্য পরিবারকল্যাণ মন্ত্রণালয়ের যুগ্ম সচিব মো রুহুল কুদ্দুছ জেলা প্রশাসক মো আমিন উল সভাপতিত্বে অনুষ্ঠানে বিশেষ অতিথি ছিলেন বিশ্ব স্বাস্থ্য সংস্থার কর্মকর্তা মাহফুজুল হক জেলা সিভিল সার্জন হাসান শাহরিয়ার কবীর জেলা সভাপতি ইসলাম
# Original summary: সব হাসপাতাল ঘোষণা
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# Predicted summary:  দুই পক্ষের সংঘর্ষে আহত
#
#
# Review
্যালয়ের উপাচার্য স আরেফিন সিদ্দিক বিশেষ অতিথি বাংলার স্থপতি সৈয়দ আবদুল্লাহ খালিদ সাবেক সাধারণ সম্পাদক আখতারুজ্জামান নাট্যজন হামিদ এবং হাসান হাফিজ সভাপতিত্ব করবেন ঢাকা বিশ্ববিদ্যালয়ের ইমেরিটাস অধ্যাপক আনিসুজ্জামান
# Original summary: বাংলা নিয়ে বই
# 1/1 [==============================] - 0s 141ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 34ms/step
# Predicted summary:  দুই পক্ষের সংঘর্ষে আহত
#
#
# Review: মে নোয়াখালী বন্ধুসভা আক্রান্ত টি পরিবারের জন শিশুর মধ্যে রঙিন জামা বিতরণ করে ঘূর্ণিঝড় নোয়াখালীর এলাকার বিভিন্ন পরিবার সবকিছু হারিয়ে জীবন করছে এমন অনেক পরিবার আছে যাদের মতো নেই নোয়াখালী বন্ধুসভা এবারের রঙিন জামা ওই সব পরিবারের মধ্যে বিতরণ করে বন্ধুরা প্রত্যেকের বাড়ি বাড়ি গিয়ে রঙিন জামা বিতরণ করে আসেন
# Original summary: বন্ধুসভার বিতরণ
# 1/1 [==============================] - 0s 141ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 28ms/step
# Predicted summary:  দুই পক্ষের সংঘর্ষে আহত
#
#
# Review: টাটা মোটরস ভারতের বাজারে নামে নতুন মডেলের আরেকটি গাড়ি পশ্চিমবঙ্গ রাজ্যের রাজধানী কলকাতায় দাম নির্ধারণ করা হয়েছে দুই লাখ হাজার রুপি এর আগে সালে টাটা মোটরস শুধু ভারতের বাজারে এক লাখ রুপি বা দুই হাজার ডলার বিপণন শুরু করে বিশ্বের সবচেয়ে এই গাড়ি স্থানীয় বাজারে প্রত্যাশা অনুযায়ী বিক্রি না হওয়ায় সম্পূর্ণ নতুন বাজারে
# Original summary: ভারতের বাজারে নতুন গাড়ি
# 1/1 [==============================] - 0s 140ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# Predicted summary:  দুই পক্ষের সংঘর্ষে আহত
#
#
# Review: চলাকালে অগ্নিদগ্ধ হয়ে জনের প্রাণহানির ঘটনায় বিএনপির চেয়ারপারসন খালেদা জিয়াসহ চারজনের বিরুদ্ধে আদালতে করা হত্যা মামলার তদন্ত প্রতিবেদন গতকাল বৃহস্পতিবার দাখিল করেনি পুলিশ আদালত আগামী মে তদন্ত প্রতিবেদন দাখিলের আদেশ দিয়েছেন ঢাকার মহানগর হাকিম মারুফ হোসেন আদেশ দেন গতকাল মামলার তদন্ত প্রতিবেদন দাখিলের দিন ধার্য ছিল গুলশান থানার ওসি তদন্ত প্রতিবেদন দাখিল করেননি খালেদা জিয়া ছাড়া অন্য যে তিনজনের বিরুদ্ধে মামলা করা হয়েছে তাঁরা হলেন বিএনপির স্থায়ী কমিটির সদস্য রফিকুল ইসলাম মিয়া বিএনপির চেয়ারপারসনের উপদেষ্টা শমসের মবিন চৌধুরী অধ্যাপক আহমদ ফেব্রুয়ারি পরিষদের সভাপতি বি সিদ্দিকী মামলাটি করেন
# Original summary: খালেদা জিয়ার বিরুদ্ধে করা মামলার প্রতিবেদন পুলিশ
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# Predicted summary:  দুই পক্ষের সংঘর্ষে আহত
#
#
# Review: বিশ্বখ্যাত প্রযুক্তি প্রতিষ্ঠান গুগল গতকাল ফেব্রুয়ারি গুগল সুবিধার মাধ্যমে উদ্যাপন করে আন্তর্জাতিক মাতৃভাষা দিবস গুগলের অনুবাদ কাল দিনটি উদ্যাপনের এই বার্তা দেখতে পেয়েছেন বার্তায় লেখা ছিল মাতৃভাষা দিবস করুন অনুবাদ যোগ দিন ওয়েবসাইটে বাংলা ভাষার গুগল শব্দ বা যোগ করে যে কেউ অবদান রাখতে পারেন প্রতিবেদক
# Original summary: দিবস করুন যোগ দিন
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# Predicted summary:  দুই পক্ষের সংঘর্ষে আহত
#
#
# Review: খুলনা প্রকৌশল প্রযুক্তি বিশ্ববিদ্যালয়ের প্রথম বর্ষ বিএসসি ইঞ্জিনিয়ারিং ব্যাচেলর অব অ্যান্ড রিজিওনাল প্ল্যানিং এবং ব্যাচেলর অব কোর্সের ভর্তি পরীক্ষার ফল গত রোববার প্রকাশিত হয়েছে জনসংযোগ তথ্য কর্মকর্তা কুমার মজুমদার বলেন গত রোববার রাতে প্রথম হাজার জনের নামের প্রকাশ করা হয় ভর্তি পরীক্ষার ফল অন্যান্য বিশ্ববিদ্যালয়ের নোটিশ বোর্ড ওয়েবসাইটে দেখা যাচ্ছে
# Original summary: প্রথম ভর্তি পরীক্ষার ফল প্রকাশ
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted summary:  দুই পক্ষের সংঘর্ষে আহত
#
#
# Review: চকরিয়া উপজেলার ইউনিয়ন পরিষদের ইউপি নম্বর ওয়ার্ডের সদস্য পদে মে অনুষ্ঠিত হবে গত মার্চ ওই ওয়ার্ডের নির্বাচিত ইউপির সদস্য বীরেন দাশের মৃত্যু হলে স্থানীয় সরকার বিভাগ পদটি শূন্য ঘোষণা করে গত এপ্রিল স্থানীয় সরকার বিভাগ প্রজ্ঞাপন জারি করে শূন্য পদে অনুষ্ঠানের নির্দেশ দেন কক্সবাজার জেলা নির্বাচন কর্মকর্তাকে চকরিয়া উপজেলা নির্বাচন কর্মকর্তা কাজী মো নুরুল আবছার জানান তফসিল মে প্রার্থীদের মনোনয়নপত্র দাখিলের শেষ দিন মে বাছাই মে প্রার্থিতা প্রত্যাহার মে প্রতীক বরাদ্দ মে ভোট গ্রহণ
# Original summary: নম্বর মে
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# ...
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 38ms/step
# Predicted summary:  দুই পক্ষের সংঘর্ষে আহত
#
#
# Review: জামায়াতে ইসলামী বলেছে জাতির দেওয়ার আওয়ামী জামায়াত দলীয় জোটের বিরুদ্ধে লেগেছে দলের ভারপ্রাপ্ত সেক্রেটারি জেনারেল রফিকুল ইসলাম খান গতকাল শনিবার এক বিবৃতিতে কথা বলেন তিনি বলেন আওয়ামী দলীয় জোটের বিরুদ্ধে ভিত্তিহীন অপপ্রচার তাঁদের ষড়যন্ত্র জনগণ কখনো বাস্তবায়ন হতে দেবে না বিবৃতিতে জঙ্গিবাদ রুখতে হলে এখনই সব সংগঠন নিষিদ্ধ করতে হবে যে দাবি করা হয় সমালোচনা করা হয়
# Original summary: দলের বিরুদ্ধে
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# Predicted summary:  দুই পক্ষের সংঘর্ষে আহত
#
#
# Review: প্রধানমন্ত্রী শেখ হাসিনা ভারতের প্রধানমন্ত্রী নরেন্দ্র মোদি মার্চ ভিডিও কনফারেন্সের মাধ্যমে বাংলাদেশ থেকে ভারতে ইন্টারনেট ব্যান্ডউইট্থ রপ্তানি ভারতের ত্রিপুরা রাজ্য থেকে মেগাওয়াট বিদ্যুৎ আমদানি কার্যক্রমের উদ্বোধন করবেন ঢাকা প্রধানমন্ত্রী এই ভিডিও কনফারেন্সে যোগ দেবেন খবর দ্য ত্রিপুরার বিদ্যুৎ মানিক দে গত মঙ্গলবার সাংবাদিকদের বলেন দেশটির পররাষ্ট্রমন্ত্রী ত্রিপুরার মুখ্যমন্ত্রী মানিক সরকারকে ওই ভিডিও কনফারেন্সে অংশগ্রহণের অনুরোধ জানিয়েছেন মানিক দে আরও বলেন ত্রিপুরা থেকে মেগাওয়াট বিদ্যুৎ যাবে বাংলাদেশে সরবরাহ করা ওই বিদ্যুতের প্রতি ইউনিটের দাম ধরা হয়েছে সাড়ে পাঁচ টাকা বিদ্যুৎ সরবরাহের জন্য বাংলাদেশ কিলোমিটার সরবরাহ লাইন নির্মাণ করা হয়েছে
# Original summary: রপ্তানি বিদ্যুৎ উদ্বোধন মার্চ
# 1/1 [==============================] - 0s 138ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# Predicted summary:  দুই পক্ষের সংঘর্ষে আহত
#
#
# Review: অর্থ পাচার মামলার অভিযোগ গঠনের শুনানি দেড় শেষ হয়নি সময় প্রার্থনা আর নানা রকম আবেদনের পড়ে না কার্যক্রম এরই মধ্যে অভিযোগ গঠনের বিষয়ে শুনানি হয়ে গেছে গতকাল মঙ্গলবার অভিযোগ গঠনের বিষয়ে আদেশ দেওয়ার কথা থাকলেও আসামিপক্ষ আবার শুনানির জন্য সময় আবেদন করে আদালত মার্চ ফের শুনানির দিন ধার্য করেন মামলার অভিযোগ গঠনের শুনানি শুরু হয় সালের নভেম্বর এরপর শুনানির জন্য টি তারিখ নির্ধারণ করেছেন ঢাকার মহানগর দায়রা জজ আদালত
# Original summary: শেষ হলো না অভিযোগ গঠনের শুনানি
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# Predicted summary:  দুই পক্ষের সংঘর্ষে আহত
#
#
# Review: পাওয়ার অ্যান্ড এনার্জি এর উইথ ক্যাটাগরিতে চ্যাম্পিয়ন হয়েছে ইউনাইটেড ইন্টারন্যাশনাল ইউনিভার্সিটির এনার্জি দল বিদ্যুৎ জ্বালানি খনিজ সম্পদ মন্ত্রণালয় এই প্রতিযোগিতার আয়োজন করে এক কম বৈদ্যুতিক ব্যবহার করে জ্বালানি উন্নত চুলা জন্য তাদের পুরস্কার দেওয়া হয় পুরস্কার প্রদান করেন বিদ্যুৎ জ্বালানি খনিজ সম্পদ প্রতিমন্ত্রী নসরুল হামিদ বিজ্ঞপ্তি
# Original summary: পাওয়ার অ্যান্ড চ্যাম্পিয়ন দল
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# Predicted summary:  দুই পক্ষের সংঘর্ষে আহত
#
#
# Review: প্রায় বছর পর বাংলাদেশ মহিলা দলের সিলেট জেলা মহানগর শাখার কমিটি গঠন করা হয়েছে গতকাল বুধবার জেলা বিএনপির দপ্তর সম্পাদক মো হক স্বাক্ষরিত সংবাদ বিজ্ঞপ্তির মাধ্যমে কমিটি গঠনের বিষয়টি নিশ্চিত হওয়া গেছে ওই বিজ্ঞপ্তির বরাত দিয়ে মো হক জানান আগস্ট মহিলা দলের কেন্দ্রীয় সভানেত্রী আরা সাধারণ সম্পাদক শিরিন সুলতানা দুটো কমিটির অনুমোদন দেন সালের পর এটিই কেন্দ্র থেকে অনুমোদন পাওয়া কমিটি সদস্যের জেলা কমিটিতে সিলেট সিটি করপোরেশনের সাবেক কাউন্সিলর বেগম চৌধুরীকে সভানেত্রী বর্তমান কাউন্সিলর সাধারণ সম্পাদক মনোনীত করা হয়েছে সদস্যের মহানগর কমিটিতে বেগম চৌধুরীকে সভানেত্রী শাহনাজ বেগমকে সাধারণ সম্পাদক করা হয়েছে
# Original summary: বছর পর সিলেট জেলা মহিলা দলের কমিটি
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted summary:  দুই পক্ষের সংঘর্ষে আহত
#
#
# Review: nan
# Original summary: ভাষা
# 1/1 [==============================] - 0s 138ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# Predicted summary:  দুই পক্ষের সংঘর্ষে আহত
#
#
# Review: ভারতের লোকসভা নির্বাচনে রাজ্যে নির্ধারিত দিনে ভোট হতে পারে ভোট দেওয়ার সুযোগ করে দেওয়ার প্রতিবাদে বিভিন্ন তরুণ সংঘ এনজিও নারী গ্রুপ ডাক দিয়েছে গতকাল সোমবার সকাল থেকে টানা ঘণ্টা ডাক দিয়েছে কর্মসূচির কারণে সেখানে ভোট গ্রহণ বাধাগ্রস্ত হতে পারে কাল এপ্রিল এই রাজ্যে ভোট গ্রহণের কথা রয়েছে সংখ্যালঘু সম্প্রদায়ের সঙ্গে সম্প্রদায়ের আদিবাসী ত্রিপুরা সম্প্রদায়ের একটি বছর আগে সংঘর্ষ হয় ওই ঘটনার পর সম্প্রদায়ের লোকজন ত্রিপুরা রাজ্যে আশ্রয় নেয় এনডিটিভি
# Original summary: কাল ভোট হতে পারে
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted summary:  দুই পক্ষের সংঘর্ষে আহত
#
#
# Review: কুমিল্লা বিশ্ববিদ্যালয় শিক্ষক সমিতির নির্বাচনে নীল দল সাধারণ সম্পাদকসহ টি পদে জয়ী হয়েছেন প্রশাসনিক ভবনে গত রোববার ওই নির্বাচন হয় নির্বাচিতরা হলেন সভাপতি পদে মো আব্দুল্লাহ স্বতন্ত্র মোহাম্মদ কামাল হোসেন স্বতন্ত্র নীল দল থেকে সহসভাপতি পদে মো ইসলাম শেখ মোহাম্মদ হক সাধারণ সম্পাদক মেহেদী হাসান কোষাধ্যক্ষ স্বপন চন্দ্র মজুমদার প্রচার প্রকাশনা সম্পাদক আবদুল্লাহ আল মাহবুব সদস্য মিহির লাল জে এম সালমান চৌধুরী আবদুল মঈনুল হাছান নির্বাচিত হন সাদা দল থেকে নির্বাচিত শিক্ষকেরা হলেন যুগ্ম সাধারণ সম্পাদক পদে মশিউর রহমান সাহিত্য এবং সংস্কৃতি ক্রীড়া সম্পাদক ইমরান হোসেন
# Original summary: শিক্ষক সমিতির নির্বাচনে দল টি পদে জয়ী
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 22ms/step
# Predicted summary:  দুই পক্ষের সংঘর্ষে আহত
#
#
# Review: নারায়ণগঞ্জে নিহত তিন মরদেহ অজ্ঞাত হিসেবে দাফনের জন্য আঞ্জুমান মুফিদুল ইসলাম কর্তৃপক্ষের কাছে হস্তান্তর করা হয়েছে আজ বৃহস্পতিবার ঢাকা মেডিকেল কলেজ হাসপাতাল থেকে তিন নিয়ে যাওয়া হয় নিহত তিন মরদেহ রাজধানীর কবরস্থানে দাফন করা হবে পুলিশ ব্যুরো অব পরিদর্শক আলমগীর প্রথম আলোকে বলেন অজ্ঞাত তিন লাশ কেউ নিতে না আসায় কর্তৃপক্ষের আঞ্জুমান মুফিদুল ইসলামের কাছে হস্তান্তর করা হয়েছে গত আগস্ট নারায়ণগঞ্জের এক অভিযানে নিহত তিন মরদেহ ময়নাতদন্তের জন্য ঢাকা মেডিকেল কলেজ হাসপাতালের মর্গে আনা হয় কেউ লাশ নিতে না আসায় আঞ্জুমান মুফিদুল ইসলাম কর্তৃপক্ষের কাছে হস্তান্তর করা হয়
# Original summary: নিহত তিন লাশ হস্তান্তর
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted summary:  দুই পক্ষের সংঘর্ষে আহত
#
#
# Review: ঢাকা বিশ্ববিদ্যালয়ের শিক্ষাবর্ষে প্রথম বর্ষ স্নাতক সম্মান শ্রেণিতে অনলাইনে ভর্তির আগামীকাল রোববার দুপুর দুইটায় শেষ হচ্ছে ওই সময় পর্যন্ত ঢাকা বিশ্ববিদ্যালয়ের মাধ্যমে প্রার্থীরা আবেদন করতে পারবেন কাল দুপুরে ঢাকা বিশ্ববিদ্যালয়ের উপাচার্য অধ্যাপক স আরেফিন সিদ্দিক বিশ্ববিদ্যালয়ের কেন্দ্রীয় ভর্তি কার্যালয়ে আনুষ্ঠানিকভাবে শেষ করবেন আজ শনিবার বিশ্ববিদ্যালয়ের জনসংযোগ এক সংবাদ বিজ্ঞপ্তিতে তথ্য জানানো হয় আগস্ট বৃহস্পতিবার এই আবেদন প্রক্রিয়া শুরু হয় আগামী সেপ্টেম্বর ব্যবসায় শিক্ষা অনুষদভুক্ত পরীক্ষার মাধ্যমে ভর্তি পরীক্ষা শুরু হচ্ছে বিজ্ঞান অনুষদভুক্ত ভর্তি পরীক্ষা সেপ্টেম্বর কলা অনুষদের সেপ্টেম্বর শাখা পরিবর্তনের জন্য সেপ্টেম্বর এবং চারুকলা অনুষদভুক্ত ভর্তি পরীক্ষা সেপ্টেম্বর অনুষ্ঠিত হবে
# Original summary: ঢাকা বিশ্ববিদ্যালয়ে ভর্তির আবেদনের সময় শেষ কাল
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted summary:  দুই পক্ষের সংঘর্ষে আহত
#
#
# Review: রাজধানীর বিজয় গ্যাসের সিলিন্ডার বিস্ফোরণে পরিবহনের একটি বাসে আগুন ধরে যায় তবে এতে কেউ আহত হয়নি আজ শুক্রবার বেলা একটার দিকে ঘটনা ঘটে কাফরুল থানার উপপরিদর্শক এসআই সুজন চন্দ্র কর্মকার জানান গ্যাসের সিলিন্ডার বিস্ফোরণের কারণে বাসের সামনের অংশে আগুন ধরে যায় যাত্রীরা নেমে যাওয়ায় কোনো ঘটেনি পরে ফায়ার সার্ভিসের একটি ইউনিট এসে আগুন কিছুক্ষণ পরে বিজয় সরণি এলাকায় যান চলাচল স্বাভাবিক হয়
# Original summary: গ্যাস বিস্ফোরণে আগুন
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# Predicted summary:  দুই পক্ষের সংঘর্ষে আহত
#
#
# Review: ঢাকা চেম্বার অব কমার্স অ্যান্ড ইন্ডাস্ট্রির নতুন দুই হাজার উদ্যোক্তা তৈরির প্রকল্পটি আনুষ্ঠানিকভাবে উদ্বোধন হচ্ছে কাল বুধবার ঢাকায় উদ্বোধন করবেন রাষ্ট্রপতি মো আবুল হামিদ ঢাকা চেম্বার বছরের মে সংবাদ সম্মেলন করে দুই হাজার নতুন উদ্যোক্তা তৈরির প্রকল্পটির ঘোষণা দেয় অন্যদিকে নতুন উদ্যোক্তাদের ঋণসুবিধা দিতে বাংলাদেশ ব্যাংক কোটি টাকার একটি তহবিল গঠন নিয়ে এখন কাজ করছে ছাড়া অন্যান্য ব্যাংক আর্থিক প্রতিষ্ঠানের কাছ থেকে ঋণসুবিধা পাওয়ার চেষ্টা চলছে নতুন উদ্যোক্তাদের সব তথ্য ঢাকা চেম্বারের ওয়েবসাইটে এবং নতুন উদ্যোক্তাদের ওয়েবসাইটে দেওয়া হয়েছে বিজ্ঞপ্তি
# Original summary: ঢাকা চেম্বারের নতুন প্রকল্প কাল শুরু
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# Predicted summary:  দুই পক্ষের সংঘর্ষে আহত
#
#
# Review
# 1/1 [==============================] - 0s 139ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted summary:  দুই পক্ষের সংঘর্ষে আহত
#
#
# Review: ইসলামী বিশ্ববিদ্যালয়ের অধীনে দেশব্যাপী কামিল স্নাতকোত্তর পরীক্ষা স্থগিত করা হয়েছে গতকাল বুধবার দুপুরে ইসলামী বিশ্ববিদ্যালয়ের তথ্য প্রকাশনা জনসংযোগ কার্যালয়ের শাখা কর্মকর্তা মো খান স্বাক্ষরিত এক বিজ্ঞপ্তিতে তথ্য জানানো হয়েছে বিজ্ঞপ্তিতে বলা হয় বিশ্ববিদ্যালয়ের পরীক্ষা নিয়ন্ত্রক কার্যালয় সূত্রে জানানো হয়েছে আগামী থেকে ফেব্রুয়ারি পর্যন্ত অনুষ্ঠিতব্য কামিল প্রথম দ্বিতীয় পর্ব এর সব পরীক্ষা অনিবার্য স্থগিত করা হয়েছে ফেব্রুয়ারি থেকে পরের সময়সূচি অনুযায়ী অনুষ্ঠিত হবে স্থগিত করা পরীক্ষার তারিখ পরে জানানো হবে
# Original summary: থেকে পরীক্ষা স্থগিত
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# Predicted summary:  দুই পক্ষের সংঘর্ষে আহত
#
#
# Review: পাকিস্তানের প্রধানমন্ত্রী শরিফ বলেছেন ভারতের সঙ্গে যে আলোচনায় কাশ্মীরের বিষয়টি থাকবে না সেই আলোচনা হবে দুই দেশের জাতীয় নিরাপত্তা মধ্যে একটি বৈঠক বাতিল হওয়ার পরিপ্রেক্ষিতে তিনি এই মন্তব্য করলেন খবর শরিফ গত সোমবার রাজধানী মন্ত্রিসভার একটি বৈঠকে সভাপতিত্ব করেন সময় তিনি জোর দিয়ে বলেন কাশ্মীর প্রশ্নে আলোচনায় নেতারা তৃতীয় পক্ষ নয় বরং একটি গুরুত্বপূর্ণ পক্ষ
# Original summary: না কোনো লাভ নেই
# 1/1 [==============================] - 0s 119ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# Predicted summary:  দুই পক্ষের সংঘর্ষে আহত
#
#
# Review: চন্দনাইশের উত্তর সরকারি প্রাথমিক বিদ্যালয়ে জানুয়ারি সকালে অভিভাবক সমাবেশ অনুষ্ঠিত হয় বিদ্যালয় পরিচালনা কমিটির সভাপতি মোহাম্মদ আমিনুল ইসলাম চৌধুরীর সভাপতিত্বে অনুষ্ঠিত সমাবেশে প্রধান অতিথি ছিলেন সাংসদ নজরুল ইসলাম চৌধুরী অনুষ্ঠানে অতিথি ছিলেন উপজেলা শিক্ষা কর্মকর্তা আশরাফুল আলম ইউপি চেয়ারম্যান আমিন আহমেদ চৌধুরী রোকন প্রমুখ অভিভাবক সমাবেশ শেষে সংসদ সদস্য নজরুল ইসলাম চৌধুরী বিদ্যালয়ের শিক্ষার্থীদের মধ্যে দুপুরের খাবার তুলে দিয়ে ডে মিল প্রকল্প উদ্বোধন করেন এরপর প্রধান শিক্ষক আবদুল পরিচালনায় বিদ্যালয়ের প্রতিষ্ঠাতা সম্মাননা জানানো হয় আয়োজনের শেষ পর্বে শিক্ষার্থীরা সাংস্কৃতিক অনুষ্ঠান পরিবেশন করে বিজ্ঞপ্তি
# Original summary: উত্তর সরকারি প্রাথমিক সমাবেশ
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# Predicted summary:  দুই পক্ষের সংঘর্ষে আহত

# %% [markdown]
# # How to increase test prediction
# 1. Take more training data (I din't take all data because of the limitation of the GPU)
# 2. Use different LSTM for example, Bidirection LSTM and GRU
# 3. Use the beam search strategy for decoding the test sequence instead of using the greedy approach (argmax)
# 4. Remove stopword
# 5. Evaluate the performance using the BLEU score(https://machinelearningmastery.com/calculate-bleu-score-for-text-python/)
# 6. Implement pointer-generator networks and coverage mechanisms
